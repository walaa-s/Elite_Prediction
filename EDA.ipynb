# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, RocCurveDisplay, roc_curve, precision_score, f1_score, recall_score
from sklearn.svm import SVC
import re

# %% [markdown]
# ## First, Let's Understand the Data
#
# In this section, we will explore the dataset to gain insights into its structure, features, and content. Understanding the data is crucial for effective analysis and interpretation. We will examine aspects such as:
#
# Data Types: Identifying the types of each feature (e.g., numerical, categorical).
#
# Missing Values: Checking for any missing or null entries that may affect our analysis.
#
# Basic Statistics: Calculating summary statistics (mean, median, mode) to understand the distribution of the data.

# %%
traindf = pd.read_csv('train.csv')

# %%
traindf.shape
# Out:
# (6548, 24)

# %%
traindf.head()
# Out:
#                              Student ID   Age Gender   Home Region  Home City  \
# 0  4f14c50d-162e-4a15-9cf0-ec129c33bcf0  37.0    ذكر  منطقة الرياض     الرياض
# 1  0599d409-876b-41a5-af05-749ef0e77d32  21.0    ذكر    منطقة عسير  خميس مشيط
# 2  38a11c0e-4afc-4261-9c64-e94cc0a272fb  24.0    ذكر  منطقة الرياض     الرياض
# 3  1693e85b-f80e-40ce-846f-395ddcece6d3  23.0    ذكر  منطقة الرياض     الرياض
# 4  98a0e8d0-5f80-4634-afd8-322aa0902863  23.0    ذكر  منطقة الرياض     الرياض
#
#                              Program ID Program Main Category Code  \
# 0  453686d8-4023-4506-b2df-fac8b059ac26                       PCRF
# 1  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60                       APMR
# 2  e006900d-05a9-4c2b-a36f-0ffb9fce44cd                       APMR
# 3  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9                       TOSL
# 4  d32da0e9-1aed-48c3-992d-a22f9ccc741e                       CAUF
#
#   Program Sub Category Code Technology Type Program Skill Level  ...  \
# 0                      PCRF             NaN                 NaN  ...
# 1                      SWPS             NaN               متوسط  ...
# 2                       NaN             NaN               متوسط  ...
# 3                      TOSL             NaN                 NaN  ...
# 4                      SWPS         تقليدية               متوسط  ...
#
#   Completed Degree Level of Education                Education Speaciality  \
# 0              نعم        البكالوريوس                     هندسة حاسب الالي
# 1              نعم        البكالوريوس           الإذاعة والتلفزيون والفيلم
# 2              نعم        البكالوريوس               Information Technology
# 3              نعم        البكالوريوس  حوسبة تطبيقية - (مسار شبكات الحاسب)
# 4               لا        البكالوريوس              نظم المعلومات الحاسوبية
#
#                           College University Degree Score  \
# 0                             NaN                    2.44
# 1        الفنون والعلوم الإنسانية                    5.00
# 2                             NaN                    3.50
# 3                             NaN                    3.55
# 4  تكنولوجيا الاتصالات والمعلومات                    4.00
#
#   University Degree Score System Employment Status Job Type  Still Working  Y
# 0                            4.0          غير موظف      NaN            NaN  0
# 1                            5.0              طالب      NaN            NaN  0
# 2                            5.0              موظف      NaN            NaN  0
# 3                            5.0              خريج      NaN            NaN  0
# 4                            5.0               NaN      NaN            NaN  0
#
# [5 rows x 24 columns]

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6548 entries, 0 to 6547
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Student ID                      6548 non-null   object
#  1   Age                             6456 non-null   float64
#  2   Gender                          6548 non-null   object
#  3   Home Region                     6546 non-null   object
#  4   Home City                       6546 non-null   object
#  5   Program ID                      6548 non-null   object
#  6   Program Main Category Code      6548 non-null   object
#  7   Program Sub Category Code       5613 non-null   object
#  8   Technology Type                 3566 non-null   object
#  9   Program Skill Level             4902 non-null   object
#  10  Program Presentation Method     6548 non-null   object
#  11  Program Start Date              6548 non-null   object
#  12  Program End Date                6548 non-null   object
#  13  Program Days                    6548 non-null   int64
#  14  Completed Degree                6548 non-null   object
#  15  Level of Education              6522 non-null   object
#  16  Education Speaciality           6271 non-null   object
#  17  College                         2658 non-null   object
#  18  University Degree Score         6467 non-null   float64
#  19  University Degree Score System  6467 non-null   float64
#  20  Employment Status               5982 non-null   object
#  21  Job Type                        1981 non-null   object
#  22  Still Working                   1981 non-null   object
#  23  Y                               6548 non-null   int64
# dtypes: float64(3), int64(2), object(19)
# memory usage: 1.2+ MB

# %% [markdown]
# ##Converting Age from Decimal to Integer
#
# In this part of the code, we will convert the age values from decimal format to natural numbers (integers).

# %%
traindf['Age'] = traindf['Age'].astype('Int64')

# %% [markdown]
# ##Correcting Column Names with Spelling Errors
#
# In this section, we will address any spelling errors in the column names of the dataset. Accurate column names are essential for clear data interpretation and analysis.

# %%
traindf.rename(columns={'Education Speaciality': 'Education Speciality'}, inplace=True)

# %% [markdown]
# ## Identifying Unique Values for Non-Sequential Columns
#
# In this section, we will identify the unique values for columns that do not contain sequential identifiers. We will exclude specific columns from this analysis.
#
# Excluded Columns:
#
# -Student ID
#
# -Age
#
# -Program ID
#
# -Program Start Date
#
# -Program End Date
#
# -University Degree Score

# %%
excluded_columns = ['Student ID', 'Age', 'Program ID', 'Program Start Date', 'Program End Date', 'University Degree Score']

for column in traindf.columns:
    if column not in excluded_columns:
        unique_values = traindf[column].unique()
        print(f"Unique values for {column}: {unique_values}\n")
# Out:
# Unique values for Gender: ['ذكر' 'أنثى']
#
# Unique values for Home Region: ['منطقة الرياض' 'منطقة عسير' 'المنطقة الشرقية' 'منطقة مكة المكرمة'
#  'منطقة نجران' 'منطقة المدينة المنورة' 'منطقة القصيم' 'منطقة تبوك'
#  'منطقة الحدود الشمالية' 'منطقة جازان' 'منطقة الباحة' 'منطقة حائل'
#  'منطقة الجوف' nan]
#
# Unique values for Home City: ['الرياض' 'خميس مشيط' 'حفر الباطن' 'جدة' 'نجران' 'مكة المكرمة' 'ينبع'
#  'المدينة المنورة' 'الهفوف' 'بريدة' 'تبوك' 'العاصمة المقدسة' 'الأحساء'
#  'الجبيل' 'عرعر' 'أبها' 'أبو عريش' 'الدمام' 'الطائف' 'الباحة'
#  'أحد المسارحة' 'حائل' 'الدلم' 'القطيف' 'الدرعية' 'جيزان' 'جازان' 'الخبر'
#  'المجمعة' 'الخرج' 'الظهران' 'الدوادمي' 'المزاحمية' 'عنيزة' 'القنفذة'
#  'الليث' 'شرورة' 'الرس' 'صامطة' 'شقراء' 'سيهات' 'صفوى' 'سكاكا' 'البدائع'
#  'رابغ' 'رفحاء' 'بيشة' 'محايل' 'المذنب' 'الخفجي' 'رأس تنورة' 'ضمد'
#  'القريات' nan 'حوطة بني تميم' 'ضبا' 'مهد الذهب' 'بارق' 'بيش'
#  'دومة الجندل' 'صبيا' 'العرضيات' 'الحناكية' 'سراة عبيدة' 'أحد رفيدة'
#  'تربة' 'العلا' 'الحريملاء' 'بلجرشي' 'بقيق' 'القرى' 'رجال ألمع' 'المجاردة'
#  'وادي الفرع' 'محايل عسير' 'الزلفي' 'بدر' 'تثليث' 'عنك' 'البكيرية' 'ابها'
#  'بني حسن' 'رياض الخبراء' 'ثادق' 'الدرب' 'بحرة' 'الجموم' 'الغاط' 'تيماء'
#  'طبرجل' 'طريف' 'ظهران الجنوب' 'أملج']
#
# Unique values for Program Main Category Code: ['PCRF' 'APMR' 'TOSL' 'CAUF' 'ABIR' 'GRST' 'INFA' 'SERU' 'QWLM' 'DTFH']
#
# Unique values for Program Sub Category Code: ['PCRF' 'SWPS' nan 'TOSL' 'INFA' 'SRTA' 'CRDP' 'KLTM' 'ERST' 'ASCW' 'QTDY'
#  'ABIR']
#
# Unique values for Technology Type: [nan 'تقليدية' 'ناشئة' 'داعمة']
#
# Unique values for Program Skill Level: [nan 'متوسط' 'مبتدئ' 'متقدم']
#
# Unique values for Program Presentation Method: ['حضوري' 'عن بعد']
#
# Unique values for Program Days: [ 12   5  54  33  19  26  59 135  40   4 173   3  47  44  96   9  20  25
#   10 292  80  66  21 248  61]
#
# Unique values for Completed Degree: ['نعم' 'لا']
#
# Unique values for Level of Education: ['البكالوريوس' 'الماجستير' 'ثانوي' 'الدكتوراه' 'الدبلوم' nan]
#
# Unique values for Education Speciality: ['هندسة حاسب الالي' 'الإذاعة والتلفزيون والفيلم' 'Information Technology'
#  'حوسبة تطبيقية - (مسار شبكات الحاسب)' 'نظم المعلومات الحاسوبية'
#  'هندسة حاسب آلي' 'نظم معلومات' 'علوم وهندسة الحاسب الآلي' 'نظم المعلومات'
#  'علوم الحاسبات' 'علوم حاسب الي' 'تقنية المعلومات' 'Software Engineering'
#  'Computer Networking and Cyber security' 'الجغرافيا البشرية'
#  'علوم وهندسة الحاسب - ذكاء اصطناعي' 'Civil and Environmental engineering'
#  'علوم الحاسب الالي' 'الرياضيات التطبيقية' 'أمن المعلومات'
#  'شبكات الحاسب الآلي' 'علوم الحاسب' 'لغويات تطبيقية' 'علوم حاسب'
#  'تصميم منتجات' 'computer science' 'تاريخ اسلامي' nan 'هندسة شبكات'
#  'تطبيقات الحاسب الالي' 'هندسة كهربائية' 'Software engineering' 'تاريخ'
#  'علوم حاسب آلي' 'شبكات الحاسب' 'هندسة البرمجيات'
#  'نظم معلومات حاسوبيه-قواعد بيانات' 'product design'
#  'management information system' 'ENGINEER IN MARINE TECHNOLOGY'
#  'الهندسة الكهربائية' 'نظم المعلومات الإدارية' 'هندسة الكترونيات'
#  'Information System' 'الفيزياء' 'نظم معلومات حاسوبية' 'العلوم الإدارية'
#  'هندسة برمجيات' 'نظم المعلومات الادارية' 'برمجة حاسب هندسة برمجيات'
#  'تقنية معلومات' 'نظم معلومات حاسب مسار امن سيبراني' 'إدارة أعمال'
#  'جرافيك ووسائط رقمية' 'هندسة صناعية' 'الجرافيكس والوسائط المتعددة'
#  'تقنية المعلومات-الأمن السيبراني' 'Cybersecurity'
#  'هندسة الشبكات والاتصالات' 'Cybersecurity engineering'
#  'الحاسب والمعلومات' 'Information technology' 'Computer Science'
#  'Business Administration' 'Information Security' 'information technology'
#  'حاسب الى تربوي'
#  'تقنيه معلومات(لسى طالبه جامعيه بحط موعد تخرجي المتوقع ، شهاده الثانوي تخرجت بمعدل تراكمي ٩٨)'
#  'Human resources' 'برمجة الحاسب الألي' 'فيزياء' 'غير متخصص' 'Is'
#  'تقنية معلومات- امن سيبراني' 'إدارة الشبكات' 'حاسب' 'موارد بشرية'
#  'بكالوريوس تقنية معلومات (علوم حاسب)' 'حاسب آلي' 'علوم الحاسب والمعلومات'
#  'هندسة الحاسب الآلي والشبكات' 'نظم معلومات اداريه' 'هندسة الحاسب الالي'
#  'برمجة حاسب' 'ذكاء اصطناعي' 'تقنية قلب' 'ادارة اعمال' 'تربية خاصه'
#  'إدارة الأعمال' 'التربية الإسلامية' 'هندسة' 'انجليزي' 'المالية والبنوك'
#  'برمجه وقواعد بيانات' 'علوم الحاسب وتقنيه المعلومات' 'آداب إنجليزي'
#  'تصميم الازياء' 'Computer science and engineering' 'Product Design'
#  'Software Engineer' 'Cyber forensics and information system'
#  'نظم المعلومات الاداريه' 'business management' 'رياض اطفال'
#  'خدمة اجتماعيه' 'Industrial Engineer Technology' 'تسويق' 'IT'
#  'الأمن السيبراني' 'تكنولوجيا طبية حيوية' 'Cyber security'
#  'هندسة حاسب الي' 'cybersecurity' 'أحياء' 'الجغرافيا' 'نظم معلومات ادارية'
#  'صيدلة' 'حاسب آلي تقنية شبكات' 'علوم وهندسة الحاسب الالي'
#  'التصميم الجرافيكي والوسائط المتعددة' 'الرياضيات والاحصاء'
#  'Information technology cybersecurity track' 'تحليل البيانات'
#  'أمن سيبراني' 'حاسب وتقنيه المعلومات' 'بكالوريوس من كلية الإعلام والدعوة'
#  'الأنظمة' 'هندسة حاسب' 'المحاماة' 'الهندسة الميكانيكية'
#  'Computer and Information technology' 'إدارة عامة' 'Network'
#  'Mechanical engineer technology' 'computer seince' 'MIS'
#  'حاسب الي برمجيات' 'Computer science' 'كيمياء حيوية' 'cyber security'
#  'هندسة الكترونيات واتصالات' 'العلوم في الرياضيات'
#  'نظم معلومات (كلية الحاسبات)' 'هندسة الحاسب' 'تصميم المنتجات' 'MBA'
#  'مالية تطبيقي' 'تربية فنية' 'برمجة' 'علوم تقنية المعلومات'
#  'تغذية وعلوم اطعمت - دبلوم حاسب الي' 'هندسة الكترونيات مركبات'
#  'نظم معلومات الحاسب' 'Computer Information Systems' 'علوم الحاسب الآلي'
#  'تقنية المعلومات_مسار الامن السيبراني' 'تقنيه المعلومات' 'علوم حاسبات'
#  'إدارة المعلومات' 'تجارة الكترونية' 'حاسب الي - نظم المعلومات'
#  'هندسة الحاسب الالي والشبكات' 'حاسب آلي - نظم معلومات'
#  'اكترونيات صناعية وتحكم' 'نظم معلومات - علم بيانات'
#  'Telecommunication and networking engineering'
#  'علوم الحاسب وتقنية المعلومات' 'Space science'
#  'لغات وترجمه اللغه الانجليزيه' 'Electrical and Electronics Engineering'
#  'علوم الحاسب و المعلومات' 'الموارد البشرية' 'مساحة بحرية'
#  'Computer Systems Engineering' 'هندسة الحاسب الآلي وتقنية المعلومات'
#  'information system' 'امراض معدية' 'Health informatics'
#  'نظم معلومات ادارية (MIS)' 'اللغات والترجمة' 'هندسة الحاسب الآلي'
#  'Communication and computer networks' 'نظم معلومات إدارية'
#  'حاسب، نظم المعلومات' 'Information system' 'electrical engineering'
#  'هندسه حاسب' 'الأدب الإنجليزي' 'امن سيبراني'
#  'Computer science and information' 'Businesses IT' 'تجارة إلكترونية'
#  'برمجة وقواعد بيانات' 'علوم حاسب وتقنية المعلومات' 'علوم وحاسب'
#  'هندسة الحاسب والشبكات' 'شبكات وانظمة اتصال' 'رياضيات' 'الأحياء'
#  'artificial intelligence' 'Electronics and Control specialization'
#  'اتصال استراتيجي' 'برمجة الحاسب المتقدمة' 'أصول التربية' 'احصاء'
#  'هندسة ميكانيكية تطبيقية' 'نظم المعلومات ادارية' 'English' 'الكيمياء'
#  'هندسة الكترونية' 'الامن السيبراني والشبكات' 'علوم حاسب الي تطبيقي'
#  'تسويق ومبيعات' 'حاسب آلي ونظم معلومات' 'المعلوماتية الصحية'
#  'تقنية معلومات - شبكات وانظمة اتصال' 'علوم حاسبات وتقنية معلومات'
#  'إدارة اعمال' 'Beauty' 'Information system computing' 'الذكاء الاصطناعي'
#  'Computer Networks' 'علوم حاسب مسار الامن السيبراني'
#  'Information systems' 'Cyber Security' 'مهندس حاسب'
#  'المناهج وطرق التدريس' 'نظم المعلومات الإدارية MIS'
#  'كلية الاقتصاد والعلوم الادارية - نظم معلومات ادارية' 'برمجيات'
#  'computer Science' 'علم المعلومات' 'نظم معلومات الإدارية' 'إلكترونيات'
#  'محاسبة' 'تقنية معلومات وحاسوب' 'الطب والجراحة' 'Networks support system'
#  'لغة عربية' 'حاسب ألي' 'هندسة ذكاء اصطناعي'
#  'علوم الحاسب مسار ادارة المعلومات' 'Information Systems'
#  'الامن السيبراني والتحري الرقمي' 'جغرافيا' 'شبكات الحاسب الالي'
#  'Computer information systems' 'علوم حاسب الى' 'Computer engineering'
#  'It' 'شبكات وامن معلومات' 'Long Island University-New York'
#  'تقنية معلومات و حوسبة' 'اللغة العربية' 'الإعاقة العقلية'
#  'هندسة حاسب وشبكات' 'Electronics Engineering Technology'
#  'COMPUTER PROGRAMMING' 'الترجمة' 'الكلية التقنية' 'حاسب آلي نظم معلومات'
#  'علوم البيانات وتحليلها' 'ادارة المعلومات' 'مالية'
#  'بكالورويس هندسة شبكات الحاسب الألي' 'هندسة الشبكات التطبيقية'
#  'تقنية معلومات - شبكات وانظمة اتصالات' 'هندسة الشبكات و الاتصالات'
#  'هندسة حاسبات' 'CS' 'Cybersecurity Engineering' 'ادارة موارد البشرية'
#  'معلوماتية صحية' 'هندسة تقنية شبكات' 'فنون بصرية ( نحت )'
#  'Information Technologies' 'علوم حاسب Computer Science' 'إدارة إعمال'
#  'اجتماعيات' 'تقنيات التعليم' 'شبكات حاسب' 'اللغة الانجليزية'
#  'Information technology - cybersecurity' 'حاسب تقنية معلومات' 'حاسب الي'
#  'الاستشارات الوراثية' 'تقنيه معلومات' 'Computer Security'
#  'Computer Scince' 'خدمة اجتماعية' 'علوم وهندسة الحاسب' 'علوم الحاسب الى'
#  'الدراسات الإسلامية المعاصرة' 'التمويل والاستثمار' 'هندسه صناعيه'
#  'الاعلان والاتصال التسويقي' 'هندسة كهرباء'
#  'Management information system' 'علو' 'ادارة الموارد ح'
#  'quantum computing' 'حاسب الي - نظم معلومات' 'Product design'
#  'هندسة دعم أنظمة شبكات' 'Computer Since' 'اقتصاد' 'الذكاء الإصطناعي'
#  'اعلام رقمي' 'اشعه تشخيصيه' 'اللغة الانجليزية وادابها' 'الصحة العامة'
#  'كلية اللغات والترجمة، تخصص الترجمة الإنجليزية'
#  'Management Information system' 'Computer engineer' 'برمجه'
#  'نظم معلومات حاسب' 'وسائط متعددة تفاعلية' 'علوم تطبيقية' 'سكرتارية طبية'
#  'تقنية معلومات-IT'
#  'Information systems with concentration in cyber security Management and information Assurance'
#  'الترجمة بلغة الاشارة' 'Artificial Intelligence'
#  'اللغة الفرنسية والترجمة' 'هندسة حاسب آلي وشبكات'
#  'تربيه خاصة صعوبات تعلم' 'التقنيه' 'Radiology Technologist'
#  'أنظمة الاتصالات' 'أصول الدين' 'Health Information Systems'
#  'دراسات اسلاميه' 'Programming' 'هندسة البترول' 'هندسة كهرباء واتصالات'
#  'هندسة حاسوب' 'إدارة الموارد البشرية' 'نظم معلومات الاداريه'
#  'اتصلات وتقنية معلومات' 'Art and design' 'Softeare Engineering'
#  'تقنية معلومات IT' 'الحوسبة التطبيقية مسار امن السيبراني'
#  'Information System (Decision Support System)' 'حاسب الي-دعم أنظمة شبكات'
#  'الحوسبة الكمية' 'تمويل واستثمار' 'برمجه ونظم معلومات'
#  'نظم معلومات حاسب آلي' 'نظم نعلومات' 'المحاسبة' 'اداره اعمال'
#  'رياضيات تطبيقية' 'الامن السيبراني' 'هندسة مدنية' 'Public relations'
#  'الإعلام (عام)' 'هندسة تقنية' 'نظم الطاقة و الأستدامة' 'حاسب نظم معلومات'
#  'Management Information System' 'It cyber security track'
#  'هندسة انظمة شبكات الحاسب' 'تربية خاصة' 'لغات وترجمة'
#  'تكنولوجيا المعلومات' 'هندسه برمجيات' 'Computer Network'
#  'دراسات المعلومات' 'هندسة حاسبات آلية' 'هندسة الكترونيات وتحكم'
#  'حاسب آلي ونظم المعلومات' 'INTER-IoT' 'دعم فني' 'آلات دقيقة وتحكم'
#  'Computer science software engineering' 'mis' 'الرياضيات'
#  'respiratory care' 'ترجمة' 'computer engineer'
#  'Computer information system' 'الشريعة' 'علم اجتماع وخدمة المجتمع'
#  'Computer of engineering' 'هندسة ميكانيكية' 'Information security'
#  'أمن معلومات' 'مهندس انظمة شبكات' 'ادارة موارد بشرية'
#  'علوم حاسب تطبيقي - شبكات' 'لغة انجليزية'
#  'Computer Science and Engineering' 'ادارة مالية' 'art education'
#  'إعلان واتصال تسويقي' 'تصميم' 'دراسات اسلامية' 'صحافة والنشر الإلكتروني'
#  'تكنولوجيا ترجمة' 'Dental surgery' 'قانون' 'الحاسب وتقنية المعلومات'
#  'University of Dubuque' 'الشبكات وأنظمة المعلومات' 'علوم الكمبيوتر'
#  'برمجة حاسب الي' 'libraries and Information' 'علم البيانات وتحليلها'
#  'التسويق' 'Health Informatics' 'التقنية معلومات' 'الامن السبراني'
#  'Data Management' 'software engineer' 'تقنية الحاسب الالي'
#  'Management Information Systmes' 'فنون بصرية' 'Software engineer' 'PMP'
#  'language and translation' 'BSc Geology' 'حاسب الي دعم فني'
#  'دعم أنظمة الشبكات' 'كيمياء' 'network security engineering' 'طب نووي'
#  'قيادة ادارية وتسويق' 'Applied linguistics' 'علم النفس' 'علوم الاشعه'
#  'EMBA' 'نظم معلومات الادارية' 'E-Business' 'هندسة اتصالات'
#  'تخصص حاسب آلي قسم نظم المعلومات' 'الطب و الجراحة العامة'
#  'كلية علوم الحاسب والمعلومات - تخصص دراسات المعلومات'
#  'Mobile communication and security' 'Actuarial Science'
#  'Computer Engineering' 'دعم انظمة شبكات الحاسب'
#  'نظم المعلومات مسار الامن' 'Information Tehnology'
#  'إدارة معلومات كلية علوم الحاسب والمعلومات' 'الادلة الجنائية'
#  'ادارة شبكات' 'Educational Technology' 'مناهج وطرق تدريس'
#  'Information Analytics' 'دراسات إسلامية' 'computer sciences'
#  'Graphic Design & Digital Media' 'computer security'
#  'حاسب آلي \\"دراسات معلومات\\"' 'شبكات وأمن المعلومات' 'تربيه حاسب الي'
#  'هندسة كيميائية' 'علم البيانات' 'برمجه وتطوير الويب' 'فيزياء عامة'
#  'تقنية المعلومات - مسار علم البيانات والذ'
#  'هندسة الاتصالات والشبكات وتقنية المعلومات'
#  'Advanced security and digital forensic' 'تقنية ميكانيكية - تكييف وتبريد'
#  'هندسة نظم معلومات' 'بحوث العمليات' 'هندسة شبكات الحاسب' 'Chemistry'
#  'هندسة معمارية' 'تصميم داخلي' 'عمارة' 'تصميم جرافيكي ووسائط متعددة'
#  'علوم الحاسب CS' 'امن سيبراني وتحري رقمي' 'الهندسة الكيميائية' 'التاريخ'
#  'هندسه حاسب وشبكات' 'Information technology &amp; computing'
#  'كلية علوم الحاسب والمعلومات' 'تأمين واداة مخاطر' 'ادب انجليزي'
#  'ادارة عامة' 'Statistics' 'برمجة الحاسب الالي' 'البرمجة وعلوم الحاسب'
#  'تقنية هندسة الشبكات' 'إدارة اعمال.' 'العلوم الإنسانية'
#  'COMPUTER ENGINEER' 'شبكات وعلوم الحاسب الالي' 'اللغويات التطبيقية'
#  'هندسة كهربائية تطبيقية' 'Data science' 'Mathematical'
#  'Applied Computing-Computer Networks Track' 'Electrical Engineering'
#  'Management Information Systems' 'تقنية المعلومات والحوسبة'
#  'دعم أنظمة شبكات الحاسب' 'اقتصاد منزلي' 'احصاء تطبيقي' 'IS'
#  'Network telecommunication systems' 'Products design'
#  'Applied computing cyber security track' 'علوم التغذية' 'Computer'
#  'حاسب ( نظم معلومات )' 'تربية فنية + دبلوم برمجة الحاسب'
#  'حاسب نظم المعلومات' 'Computer Network and Communication' 'تقنية البرمجه'
#  'نظم المعلومات مسار علم بيانات' 'اعلان واتصال تسويقي' 'تقنية طبية'
#  'Mathematics' 'برمجة الحاسب ألي' 'علوم الحاسبب' 'علوم وهندسة الحاسبات'
#  'الهندسة الكهربائية - الكترونيات واتصالات' 'Multimedia'
#  'اللغة الإنجليزية' 'هندسة دعم أنظمة الشبكات' 'إدارة انظمة شبكات'
#  'Computer sciences' 'هندسة النظم والحاسبات' 'نظم معلومات تطبيقي'
#  'البرمجة' 'تقنيات تعليم' 'تطوير التطبيقات'
#  'حاليا طالبة هندسة برمجيات في السنة الرابعة' 'حاسب -نظم معلومات'
#  'العلوم في الاعمال الالكترونية ebusiness' 'تحضيري علمي' 'ادارة مكتبية'
#  'هندسه حاسب الالي' 'علوم حاسب آلي وبرمجه' 'هندسة علوم الحاسب الالي'
#  'ادارة نظم المعلومات' 'هندسة حاسب والشبكات' 'علم بيانات' 'تقنية شبكات'
#  'هندسة الاتصالات' 'برمجيات الحاسب' 'محاسبه' 'Engineering Management'
#  'نظم معلومات - حاسب'
#  'اعمل في الحماية والمراقبة الالكترونية-الاحوال المدنية- تخصص لغات وترجمة'
#  'علوم الحاشب' 'نظم إدارية' 'إدارة الاعمال التنفيذية'
#  'نظم المعلومات Information System' 'اداره عامه'
#  'العقيدة والمذاهب المعاصرة' 'إدارة اعمال - نظم معلومات ادارية'
#  'اللغات والترجمة اللغة الانجليزيه' 'انظمة'
#  'الامن السيبراني والادلة الرقمية' 'إداره اعمال - نظم معلومات ادارية'
#  'information System' 'شبكات' 'Networking and telecommunication system'
#  'علوم امنية' 'حاسب الي - تقنية المعلومات' 'تقنية وبرمجة الويب'
#  'Masters in Business Administration' 'حاسب آلي وتقنيات التعليم'
#  'تقنية برمجة' 'Health Information Management and Technology'
#  'هندسه شبكات واتصلات' 'Cyber forensics and information security'
#  'هندسة طبية' 'Human resources management' 'Physics' 'هندسه شبكات'
#  'بكالريوس علوم حاسب مسار نظم معلومات' 'إدارة معلومات' 'علوح حاسب'
#  'Computer Information System' 'اقتصاد كلية الاداره والاعمال'
#  'نظم معلومات (كلية الحاسب)' 'منطم معلومات' 'Software system engineering'
#  'الهندسة الطبية الحيوية' 'Computer and information technology'
#  'نظم معلومات جغرافية وخرائط' 'علوم حاسب والمعلومات' 'web devolper'
#  'بكالوريوس في هندسة البرمجيات' 'accounting' 'علاقات عامه' 'هياكل ومحركات'
#  'هندسة كهربائي' 'هندسة طبية حيوية' 'Business' 'Data Science'
#  'ادارة انظمة الشبكات' 'إدارة الأعمال/ إدارة العمليات والجودة'
#  'هندسة كهربائية اتصالات' 'هندسة الكترونية - جامعة سيري بريطانيا'
#  'Management information systems' 'الكترونيات صناعية وتحكم' 'Finance'
#  'اتصالات' 'computer information system'
#  'تقنية معلومات - مسار علم بيانات وذكاء اصطناعي' 'ادارة أعمال'
#  'الاطراف الصناعية والأجهزة المساعدة' 'نظم معلومات حاسوبيه'
#  'هندسة الشبكات' 'Computer programming' 'English language'
#  'هندسه كهربائية' 'تقنية معلومات مسار امن سيبراني'
#  'Computer Engineering Technology' 'تقنية و امن معلومات'
#  'Cybersecurity and Info Assurance' 'Computer Engineer'
#  'الأطراف الصناعية و اجهزة تقويم العظام' 'بكالوريس علوم الحاسب الالي'
#  'هندسة الالكترونيات والاتصالات' 'تجميل' 'الإدارة والأعمال' 'مسار علمي'
#  'الإعلام المتخصص' 'تدريس اللغة الانجليزيه' 'انشاءات معمارية'
#  'برمجة وتشغيل حاسبات' 'هندسة الحاسوب'
#  'تقنية معلومات مسار الامن السيبراني' 'تصميم ازياء'
#  'الإعلان والاتصال التسويقي' 'معلوماتيه صحية' 'الحاسب الآلي'
#  'دبلوم تطبيقات الحاسب (وحالياً طالبه بكالوريوس نظم معلومات ادارية بمعدل ٤.٥)'
#  'تقنية المعلومات- مسار علم البيانات والذكاء الاصطناعي' 'العمارة'
#  'Electronics and Communication' 'نظم معلومات الحاسب الالي'
#  'computer since' 'كليةالعلوم \\\\ فيزياء' 'Network Engineering'
#  'التعليم الإلكتروني' 'حاسب الالي' 'علوم حاسب - عام'
#  'Management and Human Resources' 'Computer networks'
#  'Mechanical Engieering' 'المواد البشرية' 'تقنيات الحاسب /برمجيات'
#  'Software Development' 'الوسائط المتعددة ورسومات الويب'
#  'English Literature' 'علم اجتماع' 'علوم المعلومات' 'Nutrition'
#  'احصاء رياضيات تطبيقيه' 'شبكات وانظمة اتصالات' 'علىم الحاسب الآلي'
#  'علوم القرارات' 'علم البيانات وتحليها' 'هندسة شبكات والاتصالات'
#  'رياضيات واحصاء' 'حوسبة تطبيقية مسار الامن السيبراني'
#  'Database and programming' 'مختبرات كيميائية' 'Digital media'
#  'علم الاجتماع' 'هندسة كهربائية الكترونيات / Electrical Engineering'
#  'ادارة اعمال مسار نظم معلومات ادارية' 'حاسب الي و نظم المعلومات'
#  'الكترونيات' 'Information technology IT' 'إقتصاد' 'Computer Sciences'
#  'Computer since' 'علوم الحاسب اللالي' 'البرمجة وقواعد البيانات'
#  'IT management BI' 'Sport management' 'هندسة حاسب ألي وشبكات'
#  'علوم بيانات' 'مظم معلومات مالية' 'كلية المدربين التقنين' 'تقنية ملعومات'
#  'لغات وترجمة - انجليزي' 'تقنية معلومات - امن سيبراني'
#  'علم بيانات وتحليلها' 'إدارة عامه' 'Network  System Engineer'
#  'برمجيات حاسب' 'نظم معلومات إداريه' 'شبكات وإدارة نظم'
#  'تكنولوجيا التعليم' 'Occupational therapy' 'حقوق' 'هندسة نظم الشبكات'
#  'نظم معلومات كلية الحاسب' 'جيولوجيا' 'Special education'
#  'Business And Adminstration' 'مهارات رقمية'
#  'الأمن السيبراني والتحري الرقمي' 'الهندسة الصناعية' 'امن سبراني'
#  'Data Analytics' 'telecommunication and network engineer'
#  'علوم حاسب ونظم معلومات' 'تقنية المعلومات مسار الامن السيبراني'
#  'امن المعلومات والشبكات' 'الأدب' 'هندسة قوى كهربائية'
#  'نظم معلومات جغرافية' 'هندسة الحاسب الآلي و الشبكات' 'هندسة طيران وفضاء'
#  'بكالوريس خدمة اجتماعيه' 'نظم معلومات الحاسب الآلي'
#  'حاسب -تقنية معلومات-' 'تقنية المعلومات-مسار الأمن السيبراني'
#  'Network of computer' 'الذماء الاصطناعي' 'هندسة الشبكات والإتصالات'
#  'Computer scientists' 'هندسة وأمن الشبكات'
#  'تعليم ماقبل المرحلة الابتدائية'
#  'Master of business development MBA (system design software development strategy )'
#  'العلوم في الذكاء الاصطناعي' 'Health Education' 'Construction Management'
#  'علوم تطبيقيه' 'Artifical intellegence' 'هندسة دعم انظمة شبكات'
#  'ادارة فعاليات' 'Network engineer' 'Applied Mathematics'
#  'Networking and telecommunications systems' 'علوم حاسب - امن سيبراني'
#  'الحسبة والرقابة' 'لغة انجليزيه وادابها' 'التدخل المبكر'
#  'Computer and Information Systems'
#  'تقنية المعلومات - مسار الذكاء الاصطناعي'
#  'Computer science cybersecurity' 'تطوير تطبيات' 'computer scince'
#  'علوم أسرية' 'حاسب آلي وتقنية معلومات' 'English language and literature'
#  'الاتصال والعلاقات العامة' 'ادارة اعمال تنفيذية' 'علم اجتماع وخدمة مجتمع'
#  'تقنية المعلومات - الأمن السيبراني' 'هندسة كهربائية وحاسبات'
#  'العلوم في امن المعلومات' 'management information system (MIS)'
#  'تقنية معلومات مسار (الأمن و الشبكات)' 'هندسة اتصالات والكترونيات'
#  'اعلام' 'Islamic students' 'اصول دين' 'علوم حاسب وأنظمة معلومات'
#  'حاسب-نظم معلومات CIS' 'Networks and telecommunications'
#  'الاعمال المصرفية' 'الابتكار و تصميم المنتجات'
#  'الهندسة الميكانيكية (علوم)' 'نظم معلومات - Information Systems'
#  'علوم حاسب CS' 'علم الحاسب' 'برمجة وقواعد البيانات'
#  'نظم معلومات حاسب الي' 'التربية الفنية' 'الشبكات وامن البيانات'
#  'تقنية معلومات (IT)' 'Art and Design/public relations' 'رياضيات اكتوارية'
#  'الشبكات والاتصالات' 'تقنية البرمجة' 'دراسات الإسلاميه'
#  'شبكات الحاسب و الاتصالات' 'هندسة كهربائية و إلكترونية'
#  'تطوير المواقع الالكترونية والاجهزة الذكية' 'ادارة الاعمال الالكترونية'
#  'القرأن الكريم والدراسات الاسلاميه' 'Visual Computing' 'تقنية برمجه'
#  'Conputer scince' 'Industrial and System Engineering' 'حاسب تظم معلومات'
#  'GIS' 'إحصاء' 'تقنية معلومات information technology' 'حاسب آلي تربوي'
#  'البرمجه' 'مهندس شبكات و إتصالات' 'IT Cybersecurity'
#  'Information technology and computing'
#  'CS  نظم معلومات | Information System'
#  'تقنية معلومات - شبكات وأنظمة اتصالات' 'Computer Information Systym'
#  'تصميم منتحات' 'حوسبة و ادارة اعمال' 'فيزياء وعلوم فلك' 'قيادة وتخطيط'
#  'حاسب آلي ، تقنية المعلومات' 'هندسة كمبيوتر' 'هندسة شبكات وامن معلومات'
#  'cyberSecurity and Networking' 'التوجية والاصلاح الاسري'
#  'الحاسب الآلي و طالبة ماجستير حاليا في تخصص الذكاء الاصطناعي في جامعة البحرين'
#  'تصميم منتجات - product design' 'Cs'
#  'Information Systems - Cybersecurity' 'السياحة'
#  'الحاسبات وتقنية المعلومات - نظم المعلومات' 'فيزياء عامه'
#  '(IT) Information Technology' 'احياء' 'Advanced Computer Science'
#  'هندسة إلكترونيات' 'ادارة خدمات صحية ومستشفيات' 'نطم المعلومات'
#  'علاج وظيفي' 'جامعة الملك سعود' 'Public relation'
#  'IT information technology' 'هندسة عامة'
#  'English Language and Literature' 'برمجة حاسب ونظم المعلومات'
#  'علوم وهندسة حاسب الي' 'IT - Networks and communications' 'data science'
#  'سكرتير تنفيذي' 'هندسة حاسب آلي و شبكات' 'نظم المعلومات التطبيقية'
#  'صيانة الالات الصناعية' 'MS in Industrial Engineering'
#  'Engineering of computer network systems support' 'حاسب الي -تقنية برمجه'
#  'علم معلومات' 'Information management' 'علم نفس'
#  'هندسة تقنية الالكترونيات' 'برمجة حاسب آلي' 'Networking'
#  'رياضيات مسار إحصاء' 'Biology' 'علوم الحاسب- امن سيبراني'
#  'حاسب الي وسكرتارية' 'تصميم مواقع' 'علوم حاسبات - هندسة برمجيات'
#  'ادارة أنظمة شبكات' 'تقنية وادارة المعلومات الصحية' 'اداراة اعمال'
#  'Electrical engineer' 'نظم المعلومات CIS' 'علوم حاسب و معلومات'
#  'IT:health care informatics' 'Information Science'
#  'Public administration' 'علوم الحاسب لكن خبرتي العمليه ليست قوية'
#  'حاسب و تقنية معلومات' 'هندسة كهربائية-هندسة الكترونيات واتصالات'
#  'نحت، فنون بصرية' 'BEng Computer Systems Engineering'
#  'علوم بيانات وتحليلها' 'تربية فكريه' 'هندسه ميكانيكية' 'تقنية معلزمات'
#  'CIS' 'دراسات وقضايا معاصرة']
#
# Unique values for College: [nan 'الفنون والعلوم الإنسانية' 'تكنولوجيا الاتصالات والمعلومات'
#  'العلوم الاجتماعية والصحافة والإعلام'
#  'العلوم الطبيعية والرياضيات والإحصاء' 'الهندسة والتصنيع والبناء'
#  'الأعمال والإدارة والقانون' 'التعليم' 'الصحة والرفاة'
#  'البرامج والمؤهلات العامة']
#
# Unique values for University Degree Score System: [  4.   5. 100.  nan]
#
# Unique values for Employment Status: ['غير موظف' 'طالب' 'موظف' 'خريج' nan 'موظف - طالب' 'عمل حر']
#
# Unique values for Job Type: [nan 'دوام كامل' 'تدريب' 'تطوع' 'دوام جزئي']
#
# Unique values for Still Working: [nan 'Yes' 'No']
#
# Unique values for Y: [0 1]

# %% [markdown]
# ##Identifying Duplicate Rows
#
# In this section, we will identify and extract the duplicate rows from the dataset. This is important for ensuring data quality and integrity.

# %%
duplicate_ids = traindf[traindf.duplicated()]
duplicate_ids
# Out:
#                                 Student ID   Age Gender        Home Region  \
# 1145  cc92fa1e-494d-406f-8faf-9019d15ed5d0    37    ذكر       منطقة الرياض
# 1801  7ab3d573-5a3e-4b13-bffe-9d0d4c2d5ef9    25   أنثى    المنطقة الشرقية
# 1825  d10937d0-e234-47c7-ae42-1a83961f0ad6    25    ذكر       منطقة الرياض
# 1842  a4be6795-4575-40a8-9787-ce34c2caa8be    27    ذكر       منطقة الرياض
# 2186  d454af94-e89d-42fb-b738-c26f0d11b05c    34    ذكر       منطقة الرياض
# 2247  6bb32b34-197f-4b7e-8bd4-ffa501b75558    26   أنثى       منطقة الرياض
# 2345  dd994829-ab39-4848-8736-f4cdb039091c    32    ذكر       منطقة الرياض
# 2487  a72b93e9-7fdf-479b-9233-d37b08627b30    25   أنثى       منطقة الرياض
# 2609  f2a20174-e002-45bf-a4a8-63be34062a60    24    ذكر       منطقة الباحة
# 2886  d357f52a-2c6f-4401-89f8-752d4b20f93d    24   أنثى         منطقة عسير
# 2953  2350b46c-b378-45bd-933d-63ba0e19c569    38    ذكر       منطقة الرياض
# 3409  c8a407c2-53b9-416c-a488-3bde31687fe2    23   أنثى       منطقة الرياض
# 3467  99acb823-cde0-4cc5-9125-d917ea788649  <NA>    ذكر       منطقة الرياض
# 3497  73eb52d3-4fee-43a1-a53c-f9e3b1a3d678  <NA>    ذكر       منطقة الرياض
# 3642  3b96f4fd-0490-41c6-b089-301d25983f5f    32    ذكر       منطقة الرياض
# 3740  023f77b4-1136-4049-890c-2ad8128db5ba    24    ذكر       منطقة الرياض
# 3877  732aa155-67cb-43c8-807e-278c64776829    22   أنثى       منطقة الرياض
# 4057  75f67af4-76bb-40d2-9f14-7c2d1caaaf6b    36    ذكر       منطقة الرياض
# 4189  ecbedd25-274c-439e-a31f-bbd7ac009714    32    ذكر       منطقة الرياض
# 4211  787835ff-c211-45ec-b9a1-e3b09a6bf5a0  <NA>   أنثى       منطقة الرياض
# 4426  d1307f79-aecd-4cf2-be44-12a06dfef26e    29    ذكر       منطقة الرياض
# 4434  fabd4c95-3908-4dd9-b28d-8a6f05629880    23   أنثى       منطقة الرياض
# 4569  8956ebf2-00ac-4114-bfa8-882e81090079    24   أنثى       منطقة الرياض
# 4577  7546ed99-a30b-4eaa-a3fb-e4c480a0c7d8    24   أنثى       منطقة الرياض
# 4624  b8a19194-3be3-44ea-ade2-82670fff0039    24    ذكر       منطقة الرياض
# 4650  c31f2ff9-2660-4302-b8d5-eeaabda39cc9    24   أنثى    المنطقة الشرقية
# 4718  6012cffa-1b88-488f-866d-c23e2dc60a95    23    ذكر       منطقة الرياض
# 4744  cf0f0e36-8fce-43cf-b90e-6f6316fafc5d    23    ذكر       منطقة الرياض
# 4833  d235f569-79bb-49a5-917a-3c25403f57bd    32    ذكر       منطقة الرياض
# 4920  d08e9382-e9d3-4641-97e3-0a988eb97fce    24    ذكر       منطقة الرياض
# 5061  9437c7a7-31f1-4831-9700-173b9d387276  <NA>    ذكر       منطقة الرياض
# 5098  4b468cfa-b9c5-4c8d-b07a-3d90669bf095    28    ذكر       منطقة الرياض
# 5130  7402ee0a-8471-41dd-8a5f-3b493a109427    23    ذكر       منطقة الرياض
# 5217  d7a4c8b3-c79e-437a-8f7c-5a7d7808157d    22    ذكر       منطقة الرياض
# 5291  864246f0-ec6b-4dfc-9090-48205c41181b    24    ذكر       منطقة الرياض
# 5580  6af2e476-89d2-4ecc-9a8c-ef1d5585d495    32    ذكر       منطقة الرياض
# 5917  be5a48e1-9fbb-424d-99ba-abff14e083d1    28    ذكر       منطقة الرياض
# 5919  becdeb46-b0cf-4333-a0f2-d2d284923438    39    ذكر       منطقة الرياض
# 5951  305cf870-d8da-48d3-b9c6-c93b2a3ecbb9    23   أنثى       منطقة الرياض
# 6052  1acd4e67-2970-4cc2-bcd0-ed1326379e40    35    ذكر       منطقة الرياض
# 6098  99acb823-cde0-4cc5-9125-d917ea788649  <NA>    ذكر       منطقة الرياض
# 6117  cc92fa1e-494d-406f-8faf-9019d15ed5d0    37    ذكر       منطقة الرياض
# 6242  bbdc94d6-fa9a-42d7-af9f-519ccc02f460    24    ذكر  منطقة مكة المكرمة
# 6247  2350b46c-b378-45bd-933d-63ba0e19c569    38    ذكر       منطقة الرياض
# 6270  206447b4-433d-4950-b445-7e60e75b6ca8    40    ذكر    المنطقة الشرقية
# 6294  5ac5ad29-2dd0-499e-bfd7-ca0968fbad98    28   أنثى       منطقة الرياض
# 6417  b332054e-7250-4941-942f-30ba096ebe3b    27    ذكر       منطقة الرياض
# 6488  c2f84687-de2c-46e4-83d1-5b5ac762ed94    27    ذكر       منطقة الرياض
#
#        Home City                            Program ID  \
# 1145      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 1801  حفر الباطن  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 1825      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 1842      الرياض  eaa49c92-77da-4177-9970-0146981a1b50
# 2186      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 2247      الرياض  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 2345      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 2487      الرياض  32bce2ad-426a-4096-b7d0-78b5f30bd8a0
# 2609      الباحة  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 2886   خميس مشيط  daf89fda-a75f-487c-a30c-0b65de513e32
# 2953      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 3409      الرياض  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 3467      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 3497      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 3642      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 3740      الرياض  21c233a1-0101-44e6-8af8-39d545bddaaf
# 3877      الرياض  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 4057      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 4189      الرياض  ab263106-20a8-42aa-9626-278e62ae3a49
# 4211      الرياض  46e7d55e-f11d-47c3-8310-a907c1584671
# 4426      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 4434      الرياض  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 4569      الرياض  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 4577      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 4624      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 4650     الظهران  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 4718      الرياض  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 4744      الرياض  fb8fc693-05b5-495e-a7d7-98f4cf3f7562
# 4833      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 4920      الرياض  30643e26-1fcf-43f7-bc07-4cde49ecd276
# 5061      الرياض  4995be52-1108-4880-b852-bda36ea0ee56
# 5098      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 5130      الرياض  fb8fc693-05b5-495e-a7d7-98f4cf3f7562
# 5217      الرياض  3dd29418-5f9d-4f1f-88bd-15beb922c745
# 5291      الرياض  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 5580      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 5917      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 5919      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 5951      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 6052      الرياض  0d6336e2-4a79-4c32-8f15-073f9a4f6976
# 6098      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 6117      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 6242         جدة  a342d46f-2357-4398-958c-a0a759f5d5eb
# 6247      الرياض  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 6270     الأحساء  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 6294      الرياض  1f09a274-8f35-41a1-9a5e-61a5f1cb98fc
# 6417      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
# 6488      الرياض  321e4dc8-c3c4-4173-bca5-59a0bd9f327c
#
#      Program Main Category Code Program Sub Category Code Technology Type  \
# 1145                       PCRF                      PCRF             NaN
# 1801                       TOSL                       NaN             NaN
# 1825                       PCRF                      PCRF         تقليدية
# 1842                       APMR                      SRTA         تقليدية
# 2186                       PCRF                      PCRF         تقليدية
# 2247                       TOSL                       NaN             NaN
# 2345                       PCRF                      PCRF         تقليدية
# 2487                       ABIR                      INFA           ناشئة
# 2609                       TOSL                       NaN             NaN
# 2886                       CAUF                       NaN             NaN
# 2953                       PCRF                      PCRF             NaN
# 3409                       TOSL                       NaN             NaN
# 3467                       PCRF                      PCRF             NaN
# 3497                       PCRF                      PCRF             NaN
# 3642                       PCRF                      PCRF             NaN
# 3740                       PCRF                      PCRF             NaN
# 3877                       TOSL                       NaN             NaN
# 4057                       PCRF                      PCRF         تقليدية
# 4189                       CAUF                      SWPS         تقليدية
# 4211                       ABIR                       NaN         تقليدية
# 4426                       PCRF                      PCRF         تقليدية
# 4434                       TOSL                       NaN             NaN
# 4569                       TOSL                       NaN             NaN
# 4577                       PCRF                      PCRF         تقليدية
# 4624                       PCRF                      PCRF         تقليدية
# 4650                       TOSL                       NaN             NaN
# 4718                       TOSL                       NaN             NaN
# 4744                       APMR                      QTDY         تقليدية
# 4833                       PCRF                      PCRF             NaN
# 4920                       CAUF                      SWPS         تقليدية
# 5061                       TOSL                      TOSL         تقليدية
# 5098                       PCRF                      PCRF         تقليدية
# 5130                       APMR                      QTDY         تقليدية
# 5217                       APMR                       NaN             NaN
# 5291                       TOSL                       NaN             NaN
# 5580                       PCRF                      PCRF         تقليدية
# 5917                       PCRF                      PCRF         تقليدية
# 5919                       PCRF                      PCRF         تقليدية
# 5951                       PCRF                      PCRF         تقليدية
# 6052                       PCRF                      PCRF         تقليدية
# 6098                       PCRF                      PCRF             NaN
# 6117                       PCRF                      PCRF             NaN
# 6242                       APMR                      SRTA         تقليدية
# 6247                       PCRF                      PCRF             NaN
# 6270                       TOSL                       NaN             NaN
# 6294                       TOSL                       NaN             NaN
# 6417                       PCRF                      PCRF         تقليدية
# 6488                       PCRF                      PCRF         تقليدية
#
#      Program Skill Level  ... Completed Degree Level of Education  \
# 1145               متقدم  ...              نعم        البكالوريوس
# 1801               متوسط  ...              نعم        البكالوريوس
# 1825               متوسط  ...              نعم        البكالوريوس
# 1842               متوسط  ...              نعم        البكالوريوس
# 2186               متوسط  ...              نعم        البكالوريوس
# 2247               متوسط  ...               لا        البكالوريوس
# 2345               متوسط  ...              نعم        البكالوريوس
# 2487               مبتدئ  ...              نعم        البكالوريوس
# 2609               متوسط  ...              نعم        البكالوريوس
# 2886               مبتدئ  ...              نعم        البكالوريوس
# 2953               متقدم  ...              نعم          الماجستير
# 3409               متوسط  ...              نعم        البكالوريوس
# 3467               متقدم  ...              نعم                NaN
# 3497               متقدم  ...              نعم                NaN
# 3642               متقدم  ...              نعم        البكالوريوس
# 3740                 NaN  ...              نعم        البكالوريوس
# 3877               متوسط  ...              نعم        البكالوريوس
# 4057               متوسط  ...              نعم          الماجستير
# 4189               متقدم  ...              نعم        البكالوريوس
# 4211               مبتدئ  ...              نعم        البكالوريوس
# 4426               متوسط  ...              نعم        البكالوريوس
# 4434               متوسط  ...              نعم        البكالوريوس
# 4569               متوسط  ...              نعم        البكالوريوس
# 4577               متوسط  ...              نعم            الدبلوم
# 4624               متوسط  ...              نعم        البكالوريوس
# 4650               متوسط  ...              نعم        البكالوريوس
# 4718               متوسط  ...              نعم        البكالوريوس
# 4744               مبتدئ  ...              نعم        البكالوريوس
# 4833               متقدم  ...              نعم        البكالوريوس
# 4920               مبتدئ  ...              نعم        البكالوريوس
# 5061               متقدم  ...              نعم                NaN
# 5098               متوسط  ...              نعم        البكالوريوس
# 5130               مبتدئ  ...              نعم        البكالوريوس
# 5217               متوسط  ...               لا              ثانوي
# 5291               متوسط  ...              نعم        البكالوريوس
# 5580               متوسط  ...              نعم        البكالوريوس
# 5917               متوسط  ...              نعم        البكالوريوس
# 5919               متوسط  ...              نعم        البكالوريوس
# 5951               متوسط  ...              نعم        البكالوريوس
# 6052               مبتدئ  ...              نعم        البكالوريوس
# 6098               متقدم  ...              نعم                NaN
# 6117               متقدم  ...              نعم        البكالوريوس
# 6242               متوسط  ...              نعم        البكالوريوس
# 6247               متقدم  ...              نعم          الماجستير
# 6270               متوسط  ...              نعم        البكالوريوس
# 6294               متوسط  ...              نعم          الماجستير
# 6417               متوسط  ...              نعم        البكالوريوس
# 6488               متوسط  ...              نعم        البكالوريوس
#
#                         Education Speciality                         College  \
# 1145                    تقنية معلومات وحاسوب                             NaN
# 1801                           علوم الحاسبات  تكنولوجيا الاتصالات والمعلومات
# 1825                               علوم حاسب                             NaN
# 1842                  نظم المعلومات الإدارية       الأعمال والإدارة والقانون
# 2186  Computer Networking and Cyber security                             NaN
# 2247                             علوم الحاسب                             NaN
# 2345                              مهندس حاسب                             NaN
# 2487                           هندسة برمجيات                             NaN
# 2609                         تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 2886                           علوم الحاسبات  تكنولوجيا الاتصالات والمعلومات
# 2953                           نظم المعلومات                             NaN
# 3409                           نظم المعلومات  تكنولوجيا الاتصالات والمعلومات
# 3467                                     NaN                             NaN
# 3497                                     NaN                             NaN
# 3642                      شبكات الحاسب الآلي  تكنولوجيا الاتصالات والمعلومات
# 3740                           علوم الحاسبات  تكنولوجيا الاتصالات والمعلومات
# 3877                               علوم حاسب                             NaN
# 4057                         الأمن السيبراني                             NaN
# 4189                         تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 4211                                     NaN                             NaN
# 4426                      شبكات الحاسب الآلي  تكنولوجيا الاتصالات والمعلومات
# 4434                         تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 4569                     هندسة حاسب والشبكات                             NaN
# 4577                         تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 4624                           علوم الحاسبات  تكنولوجيا الاتصالات والمعلومات
# 4650                 نظم المعلومات الحاسوبية                             NaN
# 4718                           علوم الحاسبات  تكنولوجيا الاتصالات والمعلومات
# 4744                            هندسة الحاسب                             NaN
# 4833                          هندسة حاسب آلي                             NaN
# 4920                        Computer Science                             NaN
# 5061                                     NaN                             NaN
# 5098                      شبكات الحاسب الآلي  تكنولوجيا الاتصالات والمعلومات
# 5130                              هندسة حاسب                             NaN
# 5217                               علوم حاسب                             NaN
# 5291                         تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 5580                              الكترونيات                             NaN
# 5917                   University of Dubuque                             NaN
# 5919                           إدارة الشبكات  تكنولوجيا الاتصالات والمعلومات
# 5951                         تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6052                         تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6098                                     NaN                             NaN
# 6117                    تقنية معلومات وحاسوب                             NaN
# 6242                      شبكات الحاسب الآلي  تكنولوجيا الاتصالات والمعلومات
# 6247                           نظم المعلومات                             NaN
# 6270                           علوم الحاسبات  تكنولوجيا الاتصالات والمعلومات
# 6294                  Information technology                             NaN
# 6417                        Computer Science                             NaN
# 6488                           نظم المعلومات                             NaN
#
#      University Degree Score University Degree Score System Employment Status  \
# 1145                    2.23                            4.0              موظف
# 1801                    3.00                            4.0          غير موظف
# 1825                    3.40                            5.0              موظف
# 1842                    4.00                            5.0              موظف
# 2186                    2.85                            4.0              موظف
# 2247                    3.10                            5.0          غير موظف
# 2345                    2.45                            5.0              موظف
# 2487                    4.26                            5.0              موظف
# 2609                    2.51                            4.0              موظف
# 2886                    4.00                            5.0              موظف
# 2953                    3.90                            4.0              موظف
# 3409                    4.00                            5.0          غير موظف
# 3467                     NaN                            NaN               NaN
# 3497                     NaN                            NaN               NaN
# 3642                    3.30                            5.0              موظف
# 3740                    3.00                            4.0              موظف
# 3877                    4.22                            5.0              خريج
# 4057                    4.50                            5.0              موظف
# 4189                    5.00                            5.0              موظف
# 4211                     NaN                            NaN               NaN
# 4426                    3.00                            5.0          غير موظف
# 4434                    4.00                            5.0               NaN
# 4569                    4.37                            5.0              خريج
# 4577                    4.41                            5.0               NaN
# 4624                    3.00                            5.0              موظف
# 4650                    3.80                            5.0          غير موظف
# 4718                    3.67                            5.0               NaN
# 4744                    4.20                            5.0              خريج
# 4833                    2.23                            5.0              موظف
# 4920                    4.08                            5.0          غير موظف
# 5061                     NaN                            NaN               NaN
# 5098                    2.00                            4.0              موظف
# 5130                    3.94                            5.0              خريج
# 5217                   89.00                          100.0              طالب
# 5291                    4.52                            5.0               NaN
# 5580                    4.29                            5.0              موظف
# 5917                    3.52                            4.0              موظف
# 5919                    4.62                            5.0              موظف
# 5951                    5.00                            5.0          غير موظف
# 6052                    2.00                            4.0              موظف
# 6098                     NaN                            NaN               NaN
# 6117                    2.23                            4.0              موظف
# 6242                    3.00                            5.0          غير موظف
# 6247                    3.90                            4.0              موظف
# 6270                    3.12                            4.0          غير موظف
# 6294                    4.66                            5.0          غير موظف
# 6417                    3.77                            5.0              موظف
# 6488                    3.70                            5.0              موظف
#
#        Job Type  Still Working  Y
# 1145        NaN            NaN  0
# 1801      تدريب             No  0
# 1825        NaN            NaN  0
# 1842  دوام كامل            Yes  0
# 2186        NaN            NaN  0
# 2247        NaN            NaN  0
# 2345        NaN            NaN  0
# 2487        NaN            NaN  0
# 2609      تدريب            Yes  0
# 2886  دوام كامل            Yes  0
# 2953        NaN            NaN  0
# 3409      تدريب             No  0
# 3467        NaN            NaN  0
# 3497        NaN            NaN  0
# 3642  دوام كامل            Yes  0
# 3740  دوام كامل            Yes  0
# 3877        NaN            NaN  0
# 4057        NaN            NaN  0
# 4189  دوام كامل            Yes  0
# 4211        NaN            NaN  0
# 4426  دوام كامل             No  0
# 4434        NaN            NaN  0
# 4569        NaN            NaN  0
# 4577        NaN            NaN  0
# 4624  دوام كامل            Yes  0
# 4650        NaN            NaN  0
# 4718        NaN            NaN  0
# 4744        NaN            NaN  0
# 4833        NaN            NaN  0
# 4920        NaN            NaN  0
# 5061        NaN            NaN  0
# 5098  دوام كامل            Yes  0
# 5130        NaN            NaN  0
# 5217        NaN            NaN  0
# 5291        NaN            NaN  0
# 5580        NaN            NaN  0
# 5917        NaN            NaN  0
# 5919  دوام كامل            Yes  0
# 5951  دوام كامل             No  0
# 6052  دوام كامل            Yes  0
# 6098        NaN            NaN  0
# 6117        NaN            NaN  0
# 6242      تدريب             No  0
# 6247        NaN            NaN  0
# 6270  دوام كامل             No  0
# 6294        NaN            NaN  0
# 6417        NaN            NaN  0
# 6488        NaN            NaN  0
#
# [48 rows x 24 columns]

# %% [markdown]
# ##Removing Exact Duplicate Rows
#
# In this section, we will remove the exact duplicate rows from the dataset to ensure data integrity.

# %%
traindf.drop_duplicates(inplace=True)
print(traindf)
# Out:
#                                 Student ID  Age Gender   Home Region  \
# 0     4f14c50d-162e-4a15-9cf0-ec129c33bcf0   37    ذكر  منطقة الرياض
# 1     0599d409-876b-41a5-af05-749ef0e77d32   21    ذكر    منطقة عسير
# 2     38a11c0e-4afc-4261-9c64-e94cc0a272fb   24    ذكر  منطقة الرياض
# 3     1693e85b-f80e-40ce-846f-395ddcece6d3   23    ذكر  منطقة الرياض
# 4     98a0e8d0-5f80-4634-afd8-322aa0902863   23    ذكر  منطقة الرياض
# ...                                    ...  ...    ...           ...
# 6543  cd196579-9590-441b-8787-41078f3cee25   31   أنثى  منطقة الرياض
# 6544  37bfc11c-ff8c-42dc-9cf9-0d13bb8f7131   27   أنثى  منطقة القصيم
# 6545  fc114302-a79f-439f-a08b-fe0a51cf839e   24   أنثى  منطقة الرياض
# 6546  4b6d9a36-4402-4c75-bc3a-fca927dbaf65   25    ذكر  منطقة الرياض
# 6547  008f3386-0d43-45a4-8372-b282e5a0101a   37   أنثى  منطقة الرياض
#
#       Home City                            Program ID  \
# 0        الرياض  453686d8-4023-4506-b2df-fac8b059ac26
# 1     خميس مشيط  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60
# 2        الرياض  e006900d-05a9-4c2b-a36f-0ffb9fce44cd
# 3        الرياض  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9
# 4        الرياض  d32da0e9-1aed-48c3-992d-a22f9ccc741e
# ...         ...                                   ...
# 6543     الرياض  4f8c696a-b783-4d40-9776-105f6d3bd624
# 6544      بريدة  e94942dd-8684-4746-97ae-df567b9b0a4a
# 6545     الرياض  02ae0b47-64a6-47a1-b3c5-c0e4df393c30
# 6546     الرياض  9b4cedaa-fac0-4eac-aa4b-b05b6a0c97ff
# 6547     الرياض  d8fbc53c-e042-4e45-b8c7-42b4ad0528ee
#
#      Program Main Category Code Program Sub Category Code Technology Type  \
# 0                          PCRF                      PCRF             NaN
# 1                          APMR                      SWPS             NaN
# 2                          APMR                       NaN             NaN
# 3                          TOSL                      TOSL             NaN
# 4                          CAUF                      SWPS         تقليدية
# ...                         ...                       ...             ...
# 6543                       CAUF                      SWPS             NaN
# 6544                       PCRF                      PCRF             NaN
# 6545                       PCRF                      PCRF         تقليدية
# 6546                       PCRF                      PCRF             NaN
# 6547                       CAUF                       NaN             NaN
#
#      Program Skill Level  ... Completed Degree Level of Education  \
# 0                    NaN  ...              نعم        البكالوريوس
# 1                  متوسط  ...              نعم        البكالوريوس
# 2                  متوسط  ...              نعم        البكالوريوس
# 3                    NaN  ...              نعم        البكالوريوس
# 4                  متوسط  ...               لا        البكالوريوس
# ...                  ...  ...              ...                ...
# 6543                 NaN  ...              نعم        البكالوريوس
# 6544               مبتدئ  ...              نعم        البكالوريوس
# 6545               مبتدئ  ...               لا        البكالوريوس
# 6546               متوسط  ...              نعم        البكالوريوس
# 6547               مبتدئ  ...              نعم          الماجستير
#
#                      Education Speciality                         College  \
# 0                        هندسة حاسب الالي                             NaN
# 1              الإذاعة والتلفزيون والفيلم        الفنون والعلوم الإنسانية
# 2                  Information Technology                             NaN
# 3     حوسبة تطبيقية - (مسار شبكات الحاسب)                             NaN
# 4                 نظم المعلومات الحاسوبية  تكنولوجيا الاتصالات والمعلومات
# ...                                   ...                             ...
# 6543                      تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6544                          علوم الحاسب                             NaN
# 6545                        نظم المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6546                      تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6547                 دراسات وقضايا معاصرة                             NaN
#
#      University Degree Score University Degree Score System Employment Status  \
# 0                       2.44                            4.0          غير موظف
# 1                       5.00                            5.0              طالب
# 2                       3.50                            5.0              موظف
# 3                       3.55                            5.0              خريج
# 4                       4.00                            5.0               NaN
# ...                      ...                            ...               ...
# 6543                    4.40                            5.0               NaN
# 6544                    4.46                            5.0              موظف
# 6545                    4.93                            5.0              موظف
# 6546                    4.00                            4.0          غير موظف
# 6547                    4.32                            5.0              موظف
#
#        Job Type  Still Working  Y
# 0           NaN            NaN  0
# 1           NaN            NaN  0
# 2           NaN            NaN  0
# 3           NaN            NaN  0
# 4           NaN            NaN  0
# ...         ...            ... ..
# 6543        NaN            NaN  0
# 6544        NaN            NaN  0
# 6545  دوام كامل            Yes  1
# 6546      تدريب             No  0
# 6547        NaN            NaN  0
#
# [6500 rows x 24 columns]

# %% [markdown]
# ## Cleaning Text in a Column
#
# In this section, we will define a function to clean the text in the "Education Speciality" column by capitalizing the first letter of each word, while ensuring non-alphabetic words remain unchanged.

# %%
def clean_text(text):
    if isinstance(text, str):
        text = ' '.join(word.capitalize() if any(c.isalpha() for c in word) else word for word in text.split())
        return text
    return ''
traindf['Education Speciality'] = traindf['Education Speciality'].apply(clean_text)

# %% [markdown]
# ##Standardizing City Names
#
# In this section, we will standardize the names of cities in the "Home City" column to avoid duplicates and simplify searches and translations. We will also remove the definite article "ال" for easier processing.
#
# Steps:
#
# Correct Specific City Names:
#
# Replace 'ابها' with 'أبها' for proper spelling.
#
# Replace 'مدينة المنور' with 'مدينة المنورة' for accuracy.
#
# Replace 'مكة مكرمة' with 'مكة المكرمة' for proper formatting.
#
# Replace 'جيزان' with 'جازان' for consistency.
#
# Remove the Definite Article:
#
# Use str.replace('ال', '') to remove "ال" from city names, simplifying the text.

# %%
traindf['Home City'] = traindf['Home City'].replace('ابها', 'أبها')
traindf['Home City'] = traindf['Home City'].str.replace('ال', '')
traindf['Home City'] = traindf['Home City'].replace('مدينة المنور', 'مدينة المنورة')
traindf['Home City'] = traindf['Home City'].replace('مكة مكرمة', 'مكة المكرمة')
traindf['Home City'] = traindf['Home City'].replace('جيزان', 'جازان')

# %%
excluded_columns = ['Student ID', 'Age', 'Program ID', 'Program Start Date', 'Program End Date', 'University Degree Score']

for column in traindf.columns:
    if column not in excluded_columns:
        unique_values = traindf[column].unique()
        print(f"Unique values for {column}: {unique_values}\n")
# Out:
# Unique values for Gender: ['ذكر' 'أنثى']
#
# Unique values for Home Region: ['منطقة الرياض' 'منطقة عسير' 'المنطقة الشرقية' 'منطقة مكة المكرمة'
#  'منطقة نجران' 'منطقة المدينة المنورة' 'منطقة القصيم' 'منطقة تبوك'
#  'منطقة الحدود الشمالية' 'منطقة جازان' 'منطقة الباحة' 'منطقة حائل'
#  'منطقة الجوف' nan]
#
# Unique values for Home City: ['رياض' 'خميس مشيط' 'حفر باطن' 'جدة' 'نجران' 'مكة المكرمة' 'ينبع'
#  'مدينة منورة' 'هفوف' 'بريدة' 'تبوك' 'عاصمة مقدسة' 'أحساء' 'جبيل' 'عرعر'
#  'أبها' 'أبو عريش' 'دمام' 'طائف' 'باحة' 'أحد مسارحة' 'حائل' 'دلم' 'قطيف'
#  'درعية' 'جازان' 'خبر' 'مجمعة' 'خرج' 'ظهران' 'دوادمي' 'مزاحمية' 'عنيزة'
#  'قنفذة' 'ليث' 'شرورة' 'رس' 'صامطة' 'شقراء' 'سيهات' 'صفوى' 'سكاكا' 'بدائع'
#  'رابغ' 'رفحاء' 'بيشة' 'محايل' 'مذنب' 'خفجي' 'رأس تنورة' 'ضمد' 'قريات' nan
#  'حوطة بني تميم' 'ضبا' 'مهد ذهب' 'بارق' 'بيش' 'دومة جندل' 'صبيا' 'عرضيات'
#  'حناكية' 'سراة عبيدة' 'أحد رفيدة' 'تربة' 'علا' 'حريملاء' 'بلجرشي' 'بقيق'
#  'قرى' 'رج ألمع' 'مجاردة' 'وادي فرع' 'محايل عسير' 'زلفي' 'بدر' 'تثليث'
#  'عنك' 'بكيرية' 'بني حسن' 'رياض خبراء' 'ثادق' 'درب' 'بحرة' 'جموم' 'غاط'
#  'تيماء' 'طبرجل' 'طريف' 'ظهران جنوب' 'أملج']
#
# Unique values for Program Main Category Code: ['PCRF' 'APMR' 'TOSL' 'CAUF' 'ABIR' 'GRST' 'INFA' 'SERU' 'QWLM' 'DTFH']
#
# Unique values for Program Sub Category Code: ['PCRF' 'SWPS' nan 'TOSL' 'INFA' 'SRTA' 'CRDP' 'KLTM' 'ERST' 'ASCW' 'QTDY'
#  'ABIR']
#
# Unique values for Technology Type: [nan 'تقليدية' 'ناشئة' 'داعمة']
#
# Unique values for Program Skill Level: [nan 'متوسط' 'مبتدئ' 'متقدم']
#
# Unique values for Program Presentation Method: ['حضوري' 'عن بعد']
#
# Unique values for Program Days: [ 12   5  54  33  19  26  59 135  40   4 173   3  47  44  96   9  20  25
#   10 292  80  66  21 248  61]
#
# Unique values for Completed Degree: ['نعم' 'لا']
#
# Unique values for Level of Education: ['البكالوريوس' 'الماجستير' 'ثانوي' 'الدكتوراه' 'الدبلوم' nan]
#
# Unique values for Education Speciality: ['هندسة حاسب الالي' 'الإذاعة والتلفزيون والفيلم' 'Information Technology'
#  'حوسبة تطبيقية - (مسار شبكات الحاسب)' 'نظم المعلومات الحاسوبية'
#  'هندسة حاسب آلي' 'نظم معلومات' 'علوم وهندسة الحاسب الآلي' 'نظم المعلومات'
#  'علوم الحاسبات' 'علوم حاسب الي' 'تقنية المعلومات' 'Software Engineering'
#  'Computer Networking And Cyber Security' 'الجغرافيا البشرية'
#  'علوم وهندسة الحاسب - ذكاء اصطناعي' 'Civil And Environmental Engineering'
#  'علوم الحاسب الالي' 'الرياضيات التطبيقية' 'أمن المعلومات'
#  'شبكات الحاسب الآلي' 'علوم الحاسب' 'لغويات تطبيقية' 'علوم حاسب'
#  'تصميم منتجات' 'Computer Science' 'تاريخ اسلامي' '' 'هندسة شبكات'
#  'تطبيقات الحاسب الالي' 'هندسة كهربائية' 'تاريخ' 'علوم حاسب آلي'
#  'شبكات الحاسب' 'هندسة البرمجيات' 'نظم معلومات حاسوبيه-قواعد بيانات'
#  'Product Design' 'Management Information System'
#  'Engineer In Marine Technology' 'الهندسة الكهربائية'
#  'نظم المعلومات الإدارية' 'هندسة الكترونيات' 'Information System'
#  'الفيزياء' 'نظم معلومات حاسوبية' 'العلوم الإدارية' 'هندسة برمجيات'
#  'نظم المعلومات الادارية' 'برمجة حاسب هندسة برمجيات' 'تقنية معلومات'
#  'نظم معلومات حاسب مسار امن سيبراني' 'إدارة أعمال' 'جرافيك ووسائط رقمية'
#  'هندسة صناعية' 'الجرافيكس والوسائط المتعددة'
#  'تقنية المعلومات-الأمن السيبراني' 'Cybersecurity'
#  'هندسة الشبكات والاتصالات' 'Cybersecurity Engineering'
#  'الحاسب والمعلومات' 'Business Administration' 'Information Security'
#  'حاسب الى تربوي'
#  'تقنيه معلومات(لسى طالبه جامعيه بحط موعد تخرجي المتوقع ، شهاده الثانوي تخرجت بمعدل تراكمي ٩٨)'
#  'Human Resources' 'برمجة الحاسب الألي' 'فيزياء' 'غير متخصص' 'Is'
#  'تقنية معلومات- امن سيبراني' 'إدارة الشبكات' 'حاسب' 'موارد بشرية'
#  'بكالوريوس تقنية معلومات (علوم حاسب)' 'حاسب آلي' 'علوم الحاسب والمعلومات'
#  'هندسة الحاسب الآلي والشبكات' 'نظم معلومات اداريه' 'هندسة الحاسب الالي'
#  'برمجة حاسب' 'ذكاء اصطناعي' 'تقنية قلب' 'ادارة اعمال' 'تربية خاصه'
#  'إدارة الأعمال' 'التربية الإسلامية' 'هندسة' 'انجليزي' 'المالية والبنوك'
#  'برمجه وقواعد بيانات' 'علوم الحاسب وتقنيه المعلومات' 'آداب إنجليزي'
#  'تصميم الازياء' 'Computer Science And Engineering' 'Software Engineer'
#  'Cyber Forensics And Information System' 'نظم المعلومات الاداريه'
#  'Business Management' 'رياض اطفال' 'خدمة اجتماعيه'
#  'Industrial Engineer Technology' 'تسويق' 'It' 'الأمن السيبراني'
#  'تكنولوجيا طبية حيوية' 'Cyber Security' 'هندسة حاسب الي' 'أحياء'
#  'الجغرافيا' 'نظم معلومات ادارية' 'صيدلة' 'حاسب آلي تقنية شبكات'
#  'علوم وهندسة الحاسب الالي' 'التصميم الجرافيكي والوسائط المتعددة'
#  'الرياضيات والاحصاء' 'Information Technology Cybersecurity Track'
#  'تحليل البيانات' 'أمن سيبراني' 'حاسب وتقنيه المعلومات'
#  'بكالوريوس من كلية الإعلام والدعوة' 'الأنظمة' 'هندسة حاسب' 'المحاماة'
#  'الهندسة الميكانيكية' 'Computer And Information Technology' 'إدارة عامة'
#  'Network' 'Mechanical Engineer Technology' 'Computer Seince' 'Mis'
#  'حاسب الي برمجيات' 'كيمياء حيوية' 'هندسة الكترونيات واتصالات'
#  'العلوم في الرياضيات' 'نظم معلومات (كلية الحاسبات)' 'هندسة الحاسب'
#  'تصميم المنتجات' 'Mba' 'مالية تطبيقي' 'تربية فنية' 'برمجة'
#  'علوم تقنية المعلومات' 'تغذية وعلوم اطعمت - دبلوم حاسب الي'
#  'هندسة الكترونيات مركبات' 'نظم معلومات الحاسب'
#  'Computer Information Systems' 'علوم الحاسب الآلي'
#  'تقنية المعلومات_مسار الامن السيبراني' 'تقنيه المعلومات' 'علوم حاسبات'
#  'إدارة المعلومات' 'تجارة الكترونية' 'حاسب الي - نظم المعلومات'
#  'هندسة الحاسب الالي والشبكات' 'حاسب آلي - نظم معلومات'
#  'اكترونيات صناعية وتحكم' 'نظم معلومات - علم بيانات'
#  'Telecommunication And Networking Engineering'
#  'علوم الحاسب وتقنية المعلومات' 'Space Science'
#  'لغات وترجمه اللغه الانجليزيه' 'Electrical And Electronics Engineering'
#  'علوم الحاسب و المعلومات' 'الموارد البشرية' 'مساحة بحرية'
#  'Computer Systems Engineering' 'هندسة الحاسب الآلي وتقنية المعلومات'
#  'امراض معدية' 'Health Informatics' 'نظم معلومات ادارية (mis)'
#  'اللغات والترجمة' 'هندسة الحاسب الآلي'
#  'Communication And Computer Networks' 'نظم معلومات إدارية'
#  'حاسب، نظم المعلومات' 'Electrical Engineering' 'هندسه حاسب'
#  'الأدب الإنجليزي' 'امن سيبراني' 'Computer Science And Information'
#  'Businesses It' 'تجارة إلكترونية' 'برمجة وقواعد بيانات'
#  'علوم حاسب وتقنية المعلومات' 'علوم وحاسب' 'هندسة الحاسب والشبكات'
#  'شبكات وانظمة اتصال' 'رياضيات' 'الأحياء' 'Artificial Intelligence'
#  'Electronics And Control Specialization' 'اتصال استراتيجي'
#  'برمجة الحاسب المتقدمة' 'أصول التربية' 'احصاء' 'هندسة ميكانيكية تطبيقية'
#  'نظم المعلومات ادارية' 'English' 'الكيمياء' 'هندسة الكترونية'
#  'الامن السيبراني والشبكات' 'علوم حاسب الي تطبيقي' 'تسويق ومبيعات'
#  'حاسب آلي ونظم معلومات' 'المعلوماتية الصحية'
#  'تقنية معلومات - شبكات وانظمة اتصال' 'علوم حاسبات وتقنية معلومات'
#  'إدارة اعمال' 'Beauty' 'Information System Computing' 'الذكاء الاصطناعي'
#  'Computer Networks' 'علوم حاسب مسار الامن السيبراني'
#  'Information Systems' 'مهندس حاسب' 'المناهج وطرق التدريس'
#  'نظم المعلومات الإدارية Mis'
#  'كلية الاقتصاد والعلوم الادارية - نظم معلومات ادارية' 'برمجيات'
#  'علم المعلومات' 'نظم معلومات الإدارية' 'إلكترونيات' 'محاسبة'
#  'تقنية معلومات وحاسوب' 'الطب والجراحة' 'Networks Support System'
#  'لغة عربية' 'حاسب ألي' 'هندسة ذكاء اصطناعي'
#  'علوم الحاسب مسار ادارة المعلومات' 'الامن السيبراني والتحري الرقمي'
#  'جغرافيا' 'شبكات الحاسب الالي' 'علوم حاسب الى' 'Computer Engineering'
#  'شبكات وامن معلومات' 'Long Island University-new York'
#  'تقنية معلومات و حوسبة' 'اللغة العربية' 'الإعاقة العقلية'
#  'هندسة حاسب وشبكات' 'Electronics Engineering Technology'
#  'Computer Programming' 'الترجمة' 'الكلية التقنية' 'حاسب آلي نظم معلومات'
#  'علوم البيانات وتحليلها' 'ادارة المعلومات' 'مالية'
#  'بكالورويس هندسة شبكات الحاسب الألي' 'هندسة الشبكات التطبيقية'
#  'تقنية معلومات - شبكات وانظمة اتصالات' 'هندسة الشبكات و الاتصالات'
#  'هندسة حاسبات' 'Cs' 'ادارة موارد البشرية' 'معلوماتية صحية'
#  'هندسة تقنية شبكات' 'فنون بصرية ( نحت )' 'Information Technologies'
#  'علوم حاسب Computer Science' 'إدارة إعمال' 'اجتماعيات' 'تقنيات التعليم'
#  'شبكات حاسب' 'اللغة الانجليزية' 'Information Technology - Cybersecurity'
#  'حاسب تقنية معلومات' 'حاسب الي' 'الاستشارات الوراثية' 'تقنيه معلومات'
#  'Computer Security' 'Computer Scince' 'خدمة اجتماعية'
#  'علوم وهندسة الحاسب' 'علوم الحاسب الى' 'الدراسات الإسلامية المعاصرة'
#  'التمويل والاستثمار' 'هندسه صناعيه' 'الاعلان والاتصال التسويقي'
#  'هندسة كهرباء' 'علو' 'ادارة الموارد ح' 'Quantum Computing'
#  'حاسب الي - نظم معلومات' 'هندسة دعم أنظمة شبكات' 'Computer Since'
#  'اقتصاد' 'الذكاء الإصطناعي' 'اعلام رقمي' 'اشعه تشخيصيه'
#  'اللغة الانجليزية وادابها' 'الصحة العامة'
#  'كلية اللغات والترجمة، تخصص الترجمة الإنجليزية' 'Computer Engineer'
#  'برمجه' 'نظم معلومات حاسب' 'وسائط متعددة تفاعلية' 'علوم تطبيقية'
#  'سكرتارية طبية' 'تقنية معلومات-it'
#  'Information Systems With Concentration In Cyber Security Management And Information Assurance'
#  'الترجمة بلغة الاشارة' 'اللغة الفرنسية والترجمة' 'هندسة حاسب آلي وشبكات'
#  'تربيه خاصة صعوبات تعلم' 'التقنيه' 'Radiology Technologist'
#  'أنظمة الاتصالات' 'أصول الدين' 'Health Information Systems'
#  'دراسات اسلاميه' 'Programming' 'هندسة البترول' 'هندسة كهرباء واتصالات'
#  'هندسة حاسوب' 'إدارة الموارد البشرية' 'نظم معلومات الاداريه'
#  'اتصلات وتقنية معلومات' 'Art And Design' 'Softeare Engineering'
#  'تقنية معلومات It' 'الحوسبة التطبيقية مسار امن السيبراني'
#  'Information System (decision Support System)' 'حاسب الي-دعم أنظمة شبكات'
#  'الحوسبة الكمية' 'تمويل واستثمار' 'برمجه ونظم معلومات'
#  'نظم معلومات حاسب آلي' 'نظم نعلومات' 'المحاسبة' 'اداره اعمال'
#  'رياضيات تطبيقية' 'الامن السيبراني' 'هندسة مدنية' 'Public Relations'
#  'الإعلام (عام)' 'هندسة تقنية' 'نظم الطاقة و الأستدامة' 'حاسب نظم معلومات'
#  'It Cyber Security Track' 'هندسة انظمة شبكات الحاسب' 'تربية خاصة'
#  'لغات وترجمة' 'تكنولوجيا المعلومات' 'هندسه برمجيات' 'Computer Network'
#  'دراسات المعلومات' 'هندسة حاسبات آلية' 'هندسة الكترونيات وتحكم'
#  'حاسب آلي ونظم المعلومات' 'Inter-iot' 'دعم فني' 'آلات دقيقة وتحكم'
#  'Computer Science Software Engineering' 'الرياضيات' 'Respiratory Care'
#  'ترجمة' 'Computer Information System' 'الشريعة'
#  'علم اجتماع وخدمة المجتمع' 'Computer Of Engineering' 'هندسة ميكانيكية'
#  'أمن معلومات' 'مهندس انظمة شبكات' 'ادارة موارد بشرية'
#  'علوم حاسب تطبيقي - شبكات' 'لغة انجليزية' 'ادارة مالية' 'Art Education'
#  'إعلان واتصال تسويقي' 'تصميم' 'دراسات اسلامية' 'صحافة والنشر الإلكتروني'
#  'تكنولوجيا ترجمة' 'Dental Surgery' 'قانون' 'الحاسب وتقنية المعلومات'
#  'University Of Dubuque' 'الشبكات وأنظمة المعلومات' 'علوم الكمبيوتر'
#  'برمجة حاسب الي' 'Libraries And Information' 'علم البيانات وتحليلها'
#  'التسويق' 'التقنية معلومات' 'الامن السبراني' 'Data Management'
#  'تقنية الحاسب الالي' 'Management Information Systmes' 'فنون بصرية' 'Pmp'
#  'Language And Translation' 'Bsc Geology' 'حاسب الي دعم فني'
#  'دعم أنظمة الشبكات' 'كيمياء' 'Network Security Engineering' 'طب نووي'
#  'قيادة ادارية وتسويق' 'Applied Linguistics' 'علم النفس' 'علوم الاشعه'
#  'Emba' 'نظم معلومات الادارية' 'E-business' 'هندسة اتصالات'
#  'تخصص حاسب آلي قسم نظم المعلومات' 'الطب و الجراحة العامة'
#  'كلية علوم الحاسب والمعلومات - تخصص دراسات المعلومات'
#  'Mobile Communication And Security' 'Actuarial Science'
#  'دعم انظمة شبكات الحاسب' 'نظم المعلومات مسار الامن'
#  'Information Tehnology' 'إدارة معلومات كلية علوم الحاسب والمعلومات'
#  'الادلة الجنائية' 'ادارة شبكات' 'Educational Technology'
#  'مناهج وطرق تدريس' 'Information Analytics' 'دراسات إسلامية'
#  'Computer Sciences' 'Graphic Design & Digital Media'
#  'حاسب آلي \\"دراسات معلومات\\"' 'شبكات وأمن المعلومات' 'تربيه حاسب الي'
#  'هندسة كيميائية' 'علم البيانات' 'برمجه وتطوير الويب' 'فيزياء عامة'
#  'تقنية المعلومات - مسار علم البيانات والذ'
#  'هندسة الاتصالات والشبكات وتقنية المعلومات'
#  'Advanced Security And Digital Forensic' 'تقنية ميكانيكية - تكييف وتبريد'
#  'هندسة نظم معلومات' 'بحوث العمليات' 'هندسة شبكات الحاسب' 'Chemistry'
#  'هندسة معمارية' 'تصميم داخلي' 'عمارة' 'تصميم جرافيكي ووسائط متعددة'
#  'علوم الحاسب Cs' 'امن سيبراني وتحري رقمي' 'الهندسة الكيميائية' 'التاريخ'
#  'هندسه حاسب وشبكات' 'Information Technology &amp; Computing'
#  'كلية علوم الحاسب والمعلومات' 'تأمين واداة مخاطر' 'ادب انجليزي'
#  'ادارة عامة' 'Statistics' 'برمجة الحاسب الالي' 'البرمجة وعلوم الحاسب'
#  'تقنية هندسة الشبكات' 'إدارة اعمال.' 'العلوم الإنسانية'
#  'شبكات وعلوم الحاسب الالي' 'اللغويات التطبيقية' 'هندسة كهربائية تطبيقية'
#  'Data Science' 'Mathematical' 'Applied Computing-computer Networks Track'
#  'Management Information Systems' 'تقنية المعلومات والحوسبة'
#  'دعم أنظمة شبكات الحاسب' 'اقتصاد منزلي' 'احصاء تطبيقي'
#  'Network Telecommunication Systems' 'Products Design'
#  'Applied Computing Cyber Security Track' 'علوم التغذية' 'Computer'
#  'حاسب ( نظم معلومات )' 'تربية فنية + دبلوم برمجة الحاسب'
#  'حاسب نظم المعلومات' 'Computer Network And Communication' 'تقنية البرمجه'
#  'نظم المعلومات مسار علم بيانات' 'اعلان واتصال تسويقي' 'تقنية طبية'
#  'Mathematics' 'برمجة الحاسب ألي' 'علوم الحاسبب' 'علوم وهندسة الحاسبات'
#  'الهندسة الكهربائية - الكترونيات واتصالات' 'Multimedia'
#  'اللغة الإنجليزية' 'هندسة دعم أنظمة الشبكات' 'إدارة انظمة شبكات'
#  'هندسة النظم والحاسبات' 'نظم معلومات تطبيقي' 'البرمجة' 'تقنيات تعليم'
#  'تطوير التطبيقات' 'حاليا طالبة هندسة برمجيات في السنة الرابعة'
#  'حاسب -نظم معلومات' 'العلوم في الاعمال الالكترونية Ebusiness'
#  'تحضيري علمي' 'ادارة مكتبية' 'هندسه حاسب الالي' 'علوم حاسب آلي وبرمجه'
#  'هندسة علوم الحاسب الالي' 'ادارة نظم المعلومات' 'هندسة حاسب والشبكات'
#  'علم بيانات' 'تقنية شبكات' 'هندسة الاتصالات' 'برمجيات الحاسب' 'محاسبه'
#  'Engineering Management' 'نظم معلومات - حاسب'
#  'اعمل في الحماية والمراقبة الالكترونية-الاحوال المدنية- تخصص لغات وترجمة'
#  'علوم الحاشب' 'نظم إدارية' 'إدارة الاعمال التنفيذية'
#  'نظم المعلومات Information System' 'اداره عامه'
#  'العقيدة والمذاهب المعاصرة' 'إدارة اعمال - نظم معلومات ادارية'
#  'اللغات والترجمة اللغة الانجليزيه' 'انظمة'
#  'الامن السيبراني والادلة الرقمية' 'إداره اعمال - نظم معلومات ادارية'
#  'شبكات' 'Networking And Telecommunication System' 'علوم امنية'
#  'حاسب الي - تقنية المعلومات' 'تقنية وبرمجة الويب'
#  'Masters In Business Administration' 'حاسب آلي وتقنيات التعليم'
#  'تقنية برمجة' 'Health Information Management And Technology'
#  'هندسه شبكات واتصلات' 'Cyber Forensics And Information Security'
#  'هندسة طبية' 'Human Resources Management' 'Physics' 'هندسه شبكات'
#  'بكالريوس علوم حاسب مسار نظم معلومات' 'إدارة معلومات' 'علوح حاسب'
#  'اقتصاد كلية الاداره والاعمال' 'نظم معلومات (كلية الحاسب)' 'منطم معلومات'
#  'Software System Engineering' 'الهندسة الطبية الحيوية'
#  'نظم معلومات جغرافية وخرائط' 'علوم حاسب والمعلومات' 'Web Devolper'
#  'بكالوريوس في هندسة البرمجيات' 'Accounting' 'علاقات عامه' 'هياكل ومحركات'
#  'هندسة كهربائي' 'هندسة طبية حيوية' 'Business' 'ادارة انظمة الشبكات'
#  'إدارة الأعمال/ إدارة العمليات والجودة' 'هندسة كهربائية اتصالات'
#  'هندسة الكترونية - جامعة سيري بريطانيا' 'الكترونيات صناعية وتحكم'
#  'Finance' 'اتصالات' 'تقنية معلومات - مسار علم بيانات وذكاء اصطناعي'
#  'ادارة أعمال' 'الاطراف الصناعية والأجهزة المساعدة' 'نظم معلومات حاسوبيه'
#  'هندسة الشبكات' 'English Language' 'هندسه كهربائية'
#  'تقنية معلومات مسار امن سيبراني' 'Computer Engineering Technology'
#  'تقنية و امن معلومات' 'Cybersecurity And Info Assurance'
#  'الأطراف الصناعية و اجهزة تقويم العظام' 'بكالوريس علوم الحاسب الالي'
#  'هندسة الالكترونيات والاتصالات' 'تجميل' 'الإدارة والأعمال' 'مسار علمي'
#  'الإعلام المتخصص' 'تدريس اللغة الانجليزيه' 'انشاءات معمارية'
#  'برمجة وتشغيل حاسبات' 'هندسة الحاسوب'
#  'تقنية معلومات مسار الامن السيبراني' 'تصميم ازياء'
#  'الإعلان والاتصال التسويقي' 'معلوماتيه صحية' 'الحاسب الآلي'
#  'دبلوم تطبيقات الحاسب (وحالياً طالبه بكالوريوس نظم معلومات ادارية بمعدل ٤.٥)'
#  'تقنية المعلومات- مسار علم البيانات والذكاء الاصطناعي' 'العمارة'
#  'Electronics And Communication' 'نظم معلومات الحاسب الالي'
#  'كليةالعلوم \\\\ فيزياء' 'Network Engineering' 'التعليم الإلكتروني'
#  'حاسب الالي' 'علوم حاسب - عام' 'Management And Human Resources'
#  'Mechanical Engieering' 'المواد البشرية' 'تقنيات الحاسب /برمجيات'
#  'Software Development' 'الوسائط المتعددة ورسومات الويب'
#  'English Literature' 'علم اجتماع' 'علوم المعلومات' 'Nutrition'
#  'احصاء رياضيات تطبيقيه' 'شبكات وانظمة اتصالات' 'علىم الحاسب الآلي'
#  'علوم القرارات' 'علم البيانات وتحليها' 'هندسة شبكات والاتصالات'
#  'رياضيات واحصاء' 'حوسبة تطبيقية مسار الامن السيبراني'
#  'Database And Programming' 'مختبرات كيميائية' 'Digital Media'
#  'علم الاجتماع' 'هندسة كهربائية الكترونيات / Electrical Engineering'
#  'ادارة اعمال مسار نظم معلومات ادارية' 'حاسب الي و نظم المعلومات'
#  'الكترونيات' 'Information Technology It' 'إقتصاد' 'علوم الحاسب اللالي'
#  'البرمجة وقواعد البيانات' 'It Management Bi' 'Sport Management'
#  'هندسة حاسب ألي وشبكات' 'علوم بيانات' 'مظم معلومات مالية'
#  'كلية المدربين التقنين' 'تقنية ملعومات' 'لغات وترجمة - انجليزي'
#  'تقنية معلومات - امن سيبراني' 'علم بيانات وتحليلها' 'إدارة عامه'
#  'Network System Engineer' 'برمجيات حاسب' 'نظم معلومات إداريه'
#  'شبكات وإدارة نظم' 'تكنولوجيا التعليم' 'Occupational Therapy' 'حقوق'
#  'هندسة نظم الشبكات' 'نظم معلومات كلية الحاسب' 'جيولوجيا'
#  'Special Education' 'Business And Adminstration' 'مهارات رقمية'
#  'الأمن السيبراني والتحري الرقمي' 'الهندسة الصناعية' 'امن سبراني'
#  'Data Analytics' 'Telecommunication And Network Engineer'
#  'علوم حاسب ونظم معلومات' 'تقنية المعلومات مسار الامن السيبراني'
#  'امن المعلومات والشبكات' 'الأدب' 'هندسة قوى كهربائية'
#  'نظم معلومات جغرافية' 'هندسة الحاسب الآلي و الشبكات' 'هندسة طيران وفضاء'
#  'بكالوريس خدمة اجتماعيه' 'نظم معلومات الحاسب الآلي'
#  'حاسب -تقنية معلومات-' 'تقنية المعلومات-مسار الأمن السيبراني'
#  'Network Of Computer' 'الذماء الاصطناعي' 'هندسة الشبكات والإتصالات'
#  'Computer Scientists' 'هندسة وأمن الشبكات'
#  'تعليم ماقبل المرحلة الابتدائية'
#  'Master Of Business Development Mba (system Design Software Development Strategy )'
#  'العلوم في الذكاء الاصطناعي' 'Health Education' 'Construction Management'
#  'علوم تطبيقيه' 'Artifical Intellegence' 'هندسة دعم انظمة شبكات'
#  'ادارة فعاليات' 'Network Engineer' 'Applied Mathematics'
#  'Networking And Telecommunications Systems' 'علوم حاسب - امن سيبراني'
#  'الحسبة والرقابة' 'لغة انجليزيه وادابها' 'التدخل المبكر'
#  'Computer And Information Systems'
#  'تقنية المعلومات - مسار الذكاء الاصطناعي'
#  'Computer Science Cybersecurity' 'تطوير تطبيات' 'علوم أسرية'
#  'حاسب آلي وتقنية معلومات' 'English Language And Literature'
#  'الاتصال والعلاقات العامة' 'ادارة اعمال تنفيذية' 'علم اجتماع وخدمة مجتمع'
#  'تقنية المعلومات - الأمن السيبراني' 'هندسة كهربائية وحاسبات'
#  'العلوم في امن المعلومات' 'Management Information System (mis)'
#  'تقنية معلومات مسار (الأمن و الشبكات)' 'هندسة اتصالات والكترونيات'
#  'اعلام' 'Islamic Students' 'اصول دين' 'علوم حاسب وأنظمة معلومات'
#  'حاسب-نظم معلومات Cis' 'Networks And Telecommunications'
#  'الاعمال المصرفية' 'الابتكار و تصميم المنتجات'
#  'الهندسة الميكانيكية (علوم)' 'نظم معلومات - Information Systems'
#  'علوم حاسب Cs' 'علم الحاسب' 'برمجة وقواعد البيانات'
#  'نظم معلومات حاسب الي' 'التربية الفنية' 'الشبكات وامن البيانات'
#  'تقنية معلومات (it)' 'Art And Design/public Relations' 'رياضيات اكتوارية'
#  'الشبكات والاتصالات' 'تقنية البرمجة' 'دراسات الإسلاميه'
#  'شبكات الحاسب و الاتصالات' 'هندسة كهربائية و إلكترونية'
#  'تطوير المواقع الالكترونية والاجهزة الذكية' 'ادارة الاعمال الالكترونية'
#  'القرأن الكريم والدراسات الاسلاميه' 'Visual Computing' 'تقنية برمجه'
#  'Conputer Scince' 'Industrial And System Engineering' 'حاسب تظم معلومات'
#  'Gis' 'إحصاء' 'تقنية معلومات Information Technology' 'حاسب آلي تربوي'
#  'البرمجه' 'مهندس شبكات و إتصالات' 'It Cybersecurity'
#  'Information Technology And Computing'
#  'Cs نظم معلومات | Information System'
#  'تقنية معلومات - شبكات وأنظمة اتصالات' 'Computer Information Systym'
#  'تصميم منتحات' 'حوسبة و ادارة اعمال' 'فيزياء وعلوم فلك' 'قيادة وتخطيط'
#  'حاسب آلي ، تقنية المعلومات' 'هندسة كمبيوتر' 'هندسة شبكات وامن معلومات'
#  'Cybersecurity And Networking' 'التوجية والاصلاح الاسري'
#  'الحاسب الآلي و طالبة ماجستير حاليا في تخصص الذكاء الاصطناعي في جامعة البحرين'
#  'تصميم منتجات - Product Design' 'Information Systems - Cybersecurity'
#  'السياحة' 'الحاسبات وتقنية المعلومات - نظم المعلومات' 'فيزياء عامه'
#  '(it) Information Technology' 'احياء' 'Advanced Computer Science'
#  'هندسة إلكترونيات' 'ادارة خدمات صحية ومستشفيات' 'نطم المعلومات'
#  'علاج وظيفي' 'جامعة الملك سعود' 'Public Relation'
#  'It Information Technology' 'هندسة عامة' 'برمجة حاسب ونظم المعلومات'
#  'علوم وهندسة حاسب الي' 'It - Networks And Communications' 'سكرتير تنفيذي'
#  'هندسة حاسب آلي و شبكات' 'نظم المعلومات التطبيقية'
#  'صيانة الالات الصناعية' 'Ms In Industrial Engineering'
#  'Engineering Of Computer Network Systems Support' 'حاسب الي -تقنية برمجه'
#  'علم معلومات' 'Information Management' 'علم نفس'
#  'هندسة تقنية الالكترونيات' 'برمجة حاسب آلي' 'Networking'
#  'رياضيات مسار إحصاء' 'Biology' 'علوم الحاسب- امن سيبراني'
#  'حاسب الي وسكرتارية' 'تصميم مواقع' 'علوم حاسبات - هندسة برمجيات'
#  'ادارة أنظمة شبكات' 'تقنية وادارة المعلومات الصحية' 'اداراة اعمال'
#  'Electrical Engineer' 'نظم المعلومات Cis' 'علوم حاسب و معلومات'
#  'It:health Care Informatics' 'Information Science'
#  'Public Administration' 'علوم الحاسب لكن خبرتي العمليه ليست قوية'
#  'حاسب و تقنية معلومات' 'هندسة كهربائية-هندسة الكترونيات واتصالات'
#  'نحت، فنون بصرية' 'Beng Computer Systems Engineering'
#  'علوم بيانات وتحليلها' 'تربية فكريه' 'هندسه ميكانيكية' 'تقنية معلزمات'
#  'Cis' 'دراسات وقضايا معاصرة']
#
# Unique values for College: [nan 'الفنون والعلوم الإنسانية' 'تكنولوجيا الاتصالات والمعلومات'
#  'العلوم الاجتماعية والصحافة والإعلام'
#  'العلوم الطبيعية والرياضيات والإحصاء' 'الهندسة والتصنيع والبناء'
#  'الأعمال والإدارة والقانون' 'التعليم' 'الصحة والرفاة'
#  'البرامج والمؤهلات العامة']
#
# Unique values for University Degree Score System: [  4.   5. 100.  nan]
#
# Unique values for Employment Status: ['غير موظف' 'طالب' 'موظف' 'خريج' nan 'موظف - طالب' 'عمل حر']
#
# Unique values for Job Type: [nan 'دوام كامل' 'تدريب' 'تطوع' 'دوام جزئي']
#
# Unique values for Still Working: [nan 'Yes' 'No']
#
# Unique values for Y: [0 1]

# %% [markdown]
# ##Converting Values to Date and Time Format
#
# In this section, we will convert the values in the "Program Start Date" and "Program End Date" columns to a unified date and time format. This is essential for accurate date manipulation and analysis.

# %%
traindf['Program Start Date'] = pd.to_datetime(traindf['Program Start Date'])
traindf['Program End Date'] = pd.to_datetime(traindf['Program End Date'])

# %% [markdown]
# ##Printing Rows with Null Values
#
# In this section, we will identify and print the rows in the dataset that contain null (NaN) values. This is important for understanding data completeness and quality.

# %%
missing = traindf.isnull().sum().sort_values(ascending=False)
print(missing[missing > 0])
# Out:
# Still Working                     4535
# Job Type                          4535
# College                           3862
# Technology Type                   2958
# Program Skill Level               1645
# Program Sub Category Code          920
# Employment Status                  557
# Age                                 87
# University Degree Score System      76
# University Degree Score             76
# Level of Education                  22
# Home City                            2
# Home Region                          2
# dtype: int64

# %% [markdown]
# ##Standardizing Language to English
#
# In this section, we will convert all text entries in the dataset to English. This is important for consistency and ease of analysis.

# %%
translation_map = {
    'طالب': 'Student',
    'غير موظف': 'Unemployed',
    'موظف': 'Employed',
    'دوام كامل': 'Full-time',
    'دوام جزئي': 'Part-time',
    'نعم': 'Yes',
    'لا': 'No',
    'أنثى': 'Female',
    'ذكر': 'Male',
    'تقليدية': 'Traditional',
    'ناشئة': 'Emerging',
    'عن بعد': 'Remote',
    'حضوري': 'In-person',
    'داعمة': 'Supportive',
    'خريج': 'Graduate',
    'عمل حر': 'Freelance',
    'موظف - طالب': 'Employed - Student',
    'مختلطة': 'Hybrid',
    'متقدم': 'Advanced',
    'مبتدئ': 'Beginner',
    'متوسط': 'Intermediate',
    'البكالوريوس': 'Bachelor',
    'الثانوية العامة': 'High School',
    'الماجستير': 'Master',
    'الدبلوم': 'Diploma',
    'الدكتوراه': 'PhD',
    'تدريب': 'Internship',
    'ثانوي': 'Secondary',
}
traindf.replace(translation_map, inplace=True)

college_translation = {
    'الفنون والعلوم الإنسانية': 'Arts and Humanities',
    'تكنولوجيا الاتصالات والمعلومات': 'Information and Communication Technology',
    'العلوم الاجتماعية والصحافة والإعلام': 'Social Sciences, Journalism and Media',
    'العلوم الطبيعية والرياضيات والإحصاء': 'Natural Sciences, Mathematics and Statistics',
    'الهندسة والتصنيع والبناء': 'Engineering, Manufacturing and Construction',
    'الأعمال والإدارة والقانون': 'Business, Management and Law',
    'التعليم': 'Education',
    'الصحة والرفاة': 'Health and Wellness',
    'البرامج والمؤهلات العامة': 'General Programs and Qualifications',
    'العلوم الدينية': 'Religious Sciences'
}


home_region_translation = {
    'منطقة الرياض': 'Riyadh Region',
    'منطقة عسير': 'Asir Region',
    'المنطقة الشرقية': 'Eastern Province',
    'منطقة نجران': 'Najran Region',
    'منطقة مكة المكرمة': 'Makkah Region',
    'منطقة المدينة المنورة': 'Medina Region',
    'منطقة القصيم': 'Qassim Region',
    'منطقة تبوك': 'Tabuk Region',
    'منطقة جازان': 'Jazan Region',
    'منطقة حائل': 'Hail Region',
    'منطقة الباحة': 'Al-Baha Region',
    'منطقة الحدود الشمالية': 'Northern Borders Region',
    'منطقة الجوف': 'Al-Jawf Region'
}

home_city_translation = {
    'رياض': 'Riyadh',
    'خميس مشيط': 'Khamis Mushait',
    'حفر باطن': 'Hafr Al-Batin',
    'نجران': 'Najran',
    'مكة المكرمة': 'Makkah',
    'جدة': 'Jeddah',
    'ينبع': 'Yanbu',
    'مدينة منورة': 'Medina',
    'هفوف': 'Al-Hofuf',
    'بريدة': 'Buraidah',
    'تبوك': 'Tabuk',
    'عاصمة مقدسة': 'Holy Capital',
    'أحساء': 'Al-Ahsa',
    'جبيل': 'Jubail',
    'أبها': 'Abha',
    'أبو عريش': 'Abu Arish',
    'دمام': 'Dammam',
    'طائف': 'Taif',
    'أحد مسارحة': 'Ahd Musarrah',
    'حائل': 'Hail',
    'دلم': 'Dhulm',
    'قطيف': 'Qatif',
    'باحة': 'Al-Baha',
    'درعية': 'Diriyah',
    'جازان': 'Jazan',
    'مجمعة': 'Al-Majma\'ah',
    'خبر': 'Khobar',
    'خرج': 'Al-Khobar',
    'ظهران': 'Dhahran',
    'دوادمي': 'Dawadmi',
    'مزاحمية': 'Al-Muzahimiyah',
    'شرورة': 'Sharurah',
    'صامطة': 'Samta',
    'شقراء': 'Shuqairah',
    'سيهات': 'Saihat',
    'صفوى': 'Safwa',
    'سكاكا': 'Sakaka',
    'عنيزة': 'Unaizah',
    'قنفذة': 'Qunfudhah',
    'رابغ': 'Rabigh',
    'عرعر': 'Arar',
    'بيشة': 'Bisha',
    'محايل': 'Muhayil',
    'مذنب': 'Mudhnb',
    'خفجي': 'Khafji',
    'رس': 'Al-Ras',
    'رأس تنورة': 'Ras Tanura',
    'قريات': 'Qurayyat',
    'حوطة بني تميم': 'Hawta Bani Tamim',
    'ضبا': 'Duba',
    'رفحاء': 'Rafha',
    'بيش': 'Bish',
    'دومة جندل': 'Dumat Al-Jandal',
    'صبيا': 'Sabya',
    'عرضيات': 'Ardiyat',
    'حناكية': 'Hanakia',
    'سراة عبيدة': 'Saraat Abida',
    'أحد رفيدة': 'Ahd Rufaida',
    'تربة': 'Turbah',
    'علا': 'Ula',
    'حريملاء': 'Huraymila',
    'بلجرشي': 'Baljurashi',
    'بقيق': 'Buqayq',
    'قرى': 'Qura',
    'مجاردة': 'Majardah',
    'وادي فرع': 'WadiAlForaa',
    'زلفي': 'Zulfi',
    'بدر': 'Badr',
    'تثليث': 'Thulayyil',
    'عنك': 'Aynak',
    'بكيرية': 'Baqiriyah',
    'رياض خبراء': 'Riyadh Khubar',
    'ثادق': 'Thadiq',
    'درب': 'Darb',
    'غاط': 'Ghat',
    'طبرجل': 'Tabarjal',
    'طريف': 'Turaif',
    'ظهران جنوب': 'Dhahran South',
    'جموم': 'Jumum',
    'بدائع': 'badaya'
}

job_type_translation = {
    'تطوع': 'Volunteering',
}
traindf['College'] = traindf['College'].replace(college_translation)
traindf['Job Type'] = traindf['Job Type'].replace(job_type_translation)

traindf['Home Region'] = traindf['Home Region'].replace(home_region_translation)

traindf['Home City'] = traindf['Home City'].replace(home_city_translation)

# %% [markdown]
# ### Filling Null Values Based on Already Existing Information

# %%
traindf.loc[traindf['Employment Status'].isin(['Unemployed', 'Student', 'Graduate']), 'Job Type'] = 'No Job'
traindf.loc[traindf['Employment Status'].isin(['Freelance']), 'Job Type'] = 'Flexible'
traindf.loc[traindf['Employment Status'].isin(['Employed']), 'Job Type'] = 'Full-time'
traindf.loc[traindf['Employment Status'].isin(['Employed', 'Freelance']), 'Still Working'] = 'Yes'
traindf.loc[traindf['Job Type'].isin(['No Job']), 'Still Working'] = 'No'

# %% [markdown]
# ### Filling Missing Values Based on Technology Type Counts
#
# In this section, we will calculate the total count of each value in the "Technology Type" column. This helps in understanding the distribution of technology types and filling in any missing values accordingly.

# %%
print((traindf['Technology Type'] == 'Traditional').sum())
print((traindf['Technology Type'] == 'Supportive').sum())
print((traindf['Technology Type'] == 'Emerging').sum())
# Out:
# 2670
# 432
# 440

# %% [markdown]
# ### Calculating the Percentage of Each Technology Type
#
# In this section, we will calculate the percentage of each value in the "Technology Type" column to understand their distribution in the dataset.

# %%
t_percentage = (traindf['Technology Type'].eq('Traditional').sum() / traindf['Technology Type'].count()) * 100
print(f"Existing (Traditional) percentage: {t_percentage:.2f}%")
s_percentage = (traindf['Technology Type'].eq('Supportive').sum() / traindf['Technology Type'].count()) * 100
print(f"Exsiting (Supportive) percentage: {s_percentage:.2f}%")
e_percentage = (traindf['Technology Type'].eq('Emerging').sum() / traindf['Technology Type'].count()) * 100
print(f"Existing (Emerging) percentage: {e_percentage:.2f}%")
print((traindf['Technology Type']).isnull().sum())
# Out:
# Existing (Traditional) percentage: 75.38%
# Exsiting (Supportive) percentage: 12.20%
# Existing (Emerging) percentage: 12.42%
# 2958

# %% [markdown]
# ### Filling Missing Values Based on Existing Percentages
#
# In this section, we will fill the missing values in the "Technology Type" column according to the existing distribution percentages calculated earlier.
#
# - Distribution Percentages:
#
# Traditional: 75.52% (2236 entries)
#
# Supportive: 12.11% (358 entries)
#
# Emerging: 12.37% (364 entries)
#
# Total Missing Values: 2982
#
# - Filling Missing Values:
#
# Select Indices of Missing Values.
#
# Randomly Fill with Calculated Counts.

# %%
nan_indices = traindf[traindf['Technology Type'].isna()].index
random_fill = np.random.choice(nan_indices, size=2236, replace=False)
traindf.loc[random_fill, 'Technology Type'] = 'Traditional'

nan_indices = traindf[traindf['Technology Type'].isna()].index
random_fill = np.random.choice(nan_indices, size=358, replace=False)
traindf.loc[random_fill, 'Technology Type'] = 'Supportive'

nan_indices = traindf[traindf['Technology Type'].isna()].index
random_fill = np.random.choice(nan_indices, size=364, replace=False)
traindf.loc[random_fill, 'Technology Type'] = 'Emerging'

# %%
print((traindf['Technology Type']).isnull().sum())
# Out:
# 0

# %% [markdown]
# ### Calculating the Percentage of Each Program Skill Level
#
# In this section, we will calculate the percentage of each value in the "Program Skill Level" column to understand their distribution in the dataset.

# %%
b_percentage = (traindf['Program Skill Level'].eq('Beginner').sum() / traindf['Program Skill Level'].count()) * 100
print(f"Existing (Beginner) percentage: {b_percentage:.2f}%")
i_percentage = (traindf['Program Skill Level'].eq('Intermediate').sum() / traindf['Program Skill Level'].count()) * 100
print(f"Exsiting (Intermediate) percentage: {i_percentage:.2f}%")
a_percentage = (traindf['Program Skill Level'].eq('Advanced').sum() / traindf['Program Skill Level'].count()) * 100
print(f"Existing (Advanced) percentage: {a_percentage:.2f}%")

print("Nulls: ",(traindf['Program Skill Level']).isnull().sum())
# Out:
# Existing (Beginner) percentage: 42.29%
# Exsiting (Intermediate) percentage: 43.36%
# Existing (Advanced) percentage: 14.36%
# Nulls:  1645

# %% [markdown]
# ### Filling Missing Values Based on Existing Percentages for Program Skill Level
#
# In this section, we will fill the missing values in the "Program Skill Level" column according to the existing distribution percentages calculated earlier.
#
# - Distribution Percentages:
#
# Beginner: 42.02% (approximately 692 entries)
#
# Intermediate: 43.53% (approximately 716 entries)
#
# Advanced: 14.44% (approximately 237 entries)
#
# Total Missing Values: 1646
#
# - Filling Missing Values:
#
# Select Indices of Missing Values.
#
# Randomly Fill According to Calculated Counts.

# %%
nan_indices = traindf[traindf['Program Skill Level'].isna()].index
random_fill = np.random.choice(nan_indices, size=692, replace=False)
traindf.loc[random_fill, 'Program Skill Level'] = 'Beginner'

nan_indices = traindf[traindf['Program Skill Level'].isna()].index
random_fill = np.random.choice(nan_indices, size=716, replace=False)
traindf.loc[random_fill, 'Program Skill Level'] = 'Intermediate'

nan_indices = traindf[traindf['Program Skill Level'].isna()].index
random_fill = np.random.choice(nan_indices, size=237, replace=False)
traindf.loc[random_fill, 'Program Skill Level'] = 'Advanced'

# %%
print("Nulls: ",(traindf['Program Skill Level']).isnull().sum())
# Out:
# Nulls:  0

# %%
traindf[traindf['University Degree Score'].isna()]
# Out:
#                                 Student ID   Age  Gender    Home Region  \
# 146   755d7e1d-2ffb-4ce3-973d-133d1061a369  <NA>  Female  Riyadh Region
# 216   f842c0bc-a257-42fc-bf57-2e357f5f808a  <NA>    Male  Riyadh Region
# 329   64e9528e-263e-4263-a5fe-8f870ef604bd  <NA>    Male  Riyadh Region
# 718   73eb52d3-4fee-43a1-a53c-f9e3b1a3d678  <NA>    Male  Riyadh Region
# 774   10faea0d-1392-47f8-bb89-7fed48975dc2    20  Female  Riyadh Region
# ...                                    ...   ...     ...            ...
# 6365  10faea0d-1392-47f8-bb89-7fed48975dc2    20  Female  Riyadh Region
# 6392  c1633694-7f8f-464d-ade1-103d0cbc7f4a  <NA>  Female  Riyadh Region
# 6436  546d8f49-099c-4ed3-9e38-503ed7133905  <NA>  Female  Riyadh Region
# 6490  7b78f755-1fdb-4477-a2b1-753485ad9020  <NA>  Female   Jazan Region
# 6511  e2681a7d-cc27-464e-af02-bd33a078da58  <NA>    Male   Jazan Region
#
#      Home City                            Program ID  \
# 146     Riyadh  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 216     Riyadh  fc4f3306-9a9a-4577-8262-2861edf5d3cb
# 329     Riyadh  46e7d55e-f11d-47c3-8310-a907c1584671
# 718     Riyadh  1c8a5fbd-9986-486f-9d9b-b50568f2589b
# 774     Riyadh  e006900d-05a9-4c2b-a36f-0ffb9fce44cd
# ...        ...                                   ...
# 6365    Riyadh  c1ade348-9775-4501-b050-252d5c5e6468
# 6392    Riyadh  b0ee753e-5f35-4dc8-ae46-03af557569c0
# 6436    Riyadh  33bc9c70-789e-46cd-a207-f1ee3a738f43
# 6490     Jazan  65451000-39ff-4b0b-b0b4-bb2a67bcf9ed
# 6511     Jazan  65451000-39ff-4b0b-b0b4-bb2a67bcf9ed
#
#      Program Main Category Code Program Sub Category Code Technology Type  \
# 146                        PCRF                      PCRF     Traditional
# 216                        CAUF                      SWPS     Traditional
# 329                        ABIR                       NaN     Traditional
# 718                        PCRF                      PCRF     Traditional
# 774                        APMR                       NaN     Traditional
# ...                         ...                       ...             ...
# 6365                       CAUF                      SWPS     Traditional
# 6392                       APMR                       NaN        Emerging
# 6436                       APMR                      KLTM        Emerging
# 6490                       GRST                      INFA     Traditional
# 6511                       GRST                      INFA     Traditional
#
#      Program Skill Level  ... Completed Degree Level of Education  \
# 146             Advanced  ...              Yes                NaN
# 216             Beginner  ...              Yes           Bachelor
# 329             Beginner  ...              Yes           Bachelor
# 718             Advanced  ...              Yes                NaN
# 774         Intermediate  ...              Yes           Bachelor
# ...                  ...  ...              ...                ...
# 6365            Beginner  ...              Yes           Bachelor
# 6392        Intermediate  ...              Yes             Master
# 6436        Intermediate  ...              Yes          Secondary
# 6490        Intermediate  ...              Yes           Bachelor
# 6511        Intermediate  ...              Yes           Bachelor
#
#                                    Education Speciality  College  \
# 146                                                          NaN
# 216                                                          NaN
# 329                                                          NaN
# 718                                                          NaN
# 774   كلية الاقتصاد والعلوم الادارية - نظم معلومات ا...      NaN
# ...                                                 ...      ...
# 6365  كلية الاقتصاد والعلوم الادارية - نظم معلومات ا...      NaN
# 6392                                                         NaN
# 6436                                                         NaN
# 6490                                                         NaN
# 6511                                                         NaN
#
#      University Degree Score University Degree Score System Employment Status  \
# 146                      NaN                            NaN               NaN
# 216                      NaN                            NaN               NaN
# 329                      NaN                            NaN               NaN
# 718                      NaN                            NaN               NaN
# 774                      NaN                            NaN           Student
# ...                      ...                            ...               ...
# 6365                     NaN                            NaN           Student
# 6392                     NaN                            NaN               NaN
# 6436                     NaN                            NaN               NaN
# 6490                     NaN                            NaN               NaN
# 6511                     NaN                            NaN               NaN
#
#      Job Type  Still Working  Y
# 146       NaN            NaN  0
# 216       NaN            NaN  0
# 329       NaN            NaN  0
# 718       NaN            NaN  0
# 774    No Job             No  0
# ...       ...            ... ..
# 6365   No Job             No  0
# 6392      NaN            NaN  0
# 6436      NaN            NaN  0
# 6490      NaN            NaN  0
# 6511      NaN            NaN  0
#
# [76 rows x 24 columns]

# %%
traindf.dropna(subset=['University Degree Score'], inplace=True) # drop rows with missing values in 'University Degree Score' column

# %% [markdown]
# ### Filling College Values Based on Education Speciality
# The following code categorizes the "College" column based on the "Education Speciality" using predefined keywords for various fields.
#
# - Concise breakdown of the implementation:
#
# Define Keywords for Each College: Each college has specific keywords associated with it.
#
# Create Patterns: Combine keywords into a pattern for searching.
#
# Fill the College Column: Use the patterns to fill the "College" column based on matches found in the "Education Speciality".

# %%
# === الهندسة والتصنيع والبناء ===
keywordsENG = [
    'مدنية', 'المدنية', 'Civil', 'civil', 'مدنيه', 'المدنيه', 'كهربائية', 'الكهربائية', 'Electrical', 'electrical',
    'الكهربائيه', 'كهربائيه', 'كهربائي', 'ميكانيكية', 'الميكانيكية', 'Mechanical', 'mechanical', 'مكيانيكيه',
    'الميكانيكيه', 'صناعية', 'الصناعية', 'Industrial', 'industrial', 'الصناعيه', 'صناعيه', 'إلكترونية', 'الإلكترونية',
    'Electronics', 'electronics', 'الكترونيه', 'الالكترونيه', 'الكترونية', 'كيميائية', 'الكيميائية', 'Chemical', 'chemical',
    'كيميائيه', 'الكيميائيه', 'البترول', 'بترول', 'معمارية', 'معماريه', 'المعمارية', 'المعماريه', 'Architecture',
    'architecture', 'عماره', 'عمارة', 'هياكل', 'هندسة', 'هندسه', 'الهندسة', 'الهندسه', 'مساحة', 'آلات دقيقة وتحكم', 'Engineer In Marine Technology'
]
patternENG = '|'.join(keywordsENG)
traindf.loc[traindf['Education Speciality'].str.contains(patternENG, na=False), 'College'] = 'الهندسة والتصنيع والبناء'


# === تكنولوجيا الاتصالات والمعلومات ===
keywordsCS = [
    'Computer', 'CS', 'Cs', 'cs', 'Software', 'حاسب', 'برمجة', 'برمجيات', 'تكنولوجيا', 'تقنية', 'الحاسب', 'شبكات',
    'الشبكات', 'المعلومات', 'معلومات', 'نظم معلومات', 'نظم المعلومات', 'الحاسوبية', 'حاسوبية', 'أمن', 'سبراني',
    'سيبراني', 'الأمن', 'Information', 'Cybersecurity', 'ذكاء', 'الكترونيات', 'Is', 'IS', 'is', 'برمجه',
    'البرمجة', 'البرمجه', 'it', 'IT', 'It', 'swe', 'SWE', 'Swe', 'Cyber', 'cyber', 'cybersecurity', 'information',
    'Network', 'network', 'networks', 'Networking', 'net', 'Net', 'NET', 'Data', 'data', 'datascience', 'تقنيه',
    'اكترونيات', 'بيانات', 'البيانات', 'الذكاء الاصطناعي', 'الذكاء الصناعي', 'إلكترونيات', 'Computing', 'اتصالات',
    'الاتصالات', 'programming', 'Programming', 'حاسوب', 'الحاسوب', 'نظم', 'الكمبيوتر', 'كمبيوتر', 'Artificial Intelligence',
    'الحوسبة', 'الاصطناعي', 'Web', 'Softeare Engineering', 'دعم فني', 'علوم الحاشب', 'مهارات رقمية', 'Artifical Intellegence',
    'Conputer Scince', 'تطوير تطبيات', 'تطوير التطبيقات'
]
patternCS = '|'.join(keywordsCS)
traindf.loc[traindf['Education Speciality'].str.contains(patternCS, na=False), 'College'] = 'تكنولوجيا الاتصالات والمعلومات'


# === العلوم الطبيعية والرياضيات والإحصاء ===
keywordsSCI = [
    'احياء', 'الاحياء', 'أحياء', 'الأحياء', 'الجغرافيا', 'جغرافيا', 'رياضيات', 'الرياضيات',
    'كيمياء', 'الكيمياء', 'فيزياء', 'الفيزياء', 'إحصاء', 'الإحصاء', 'احصاء', 'الاحصاء',
    'Mathematics', 'mathematics', 'Mathematical', 'mathematical', 'Biology', 'biology',
    'Chemistry', 'chemistry', 'Physics', 'physics', 'Statistics', 'statistics', 'Geography', 'geography'
    'Geology', 'Space Science', 'Bsc Geology', 'جيولوجيا', 'علوم تطبيقيه'
]
patternSCI = '|'.join(keywordsSCI)
traindf.loc[traindf['Education Speciality'].str.contains(patternSCI, na=False), 'College'] = 'العلوم الطبيعية والرياضيات والإحصاء'


# === الصحة والرفاة ===
keywordsH = [
    'امراض', 'الامراض', 'Health', 'health', 'healthcare', 'Healthcare', 'تمريض', 'التمريض', 'التمريضية',
    'Nursing', 'nursing', 'صيدلة', 'Pharmacy', 'pharmacy', 'صيدله', 'الصيدلة', 'صحية', 'الصحة', 'الصحيه', 'الصحى',
    'اشعه', 'الاشعه', 'Radiology', 'radiology', 'الأشعة', 'أشعة', 'الأشعه', 'أشعه', 'Dental', 'Occupational Therapy',
    'علاج وظيفي', 'الاستشارات الوراثية', 'Respiratory Care', 'علوم أسرية', 'تجميل', 'Beauty', 'التغذية', 'بحوث العمليات', 'طب نووي', 'سكرتارية طبية'
]
patternH = '|'.join(keywordsH)
traindf.loc[traindf['Education Speciality'].str.contains(patternH, na=False), 'College'] = 'الصحة والرفاة'


# === الأعمال والإدارة والقانون ===
keywordsB = [
    'أعمال', 'Business', 'اعمال', 'محاسبة', 'Accounting', 'تمويل', 'Finance', 'تسويق', 'Marketing', 'البشرية', 'Human',
    'عامة', 'Public', 'ادارة', 'Management', 'إدارة', 'اداره', 'إداره', 'اقتصاد', 'Economics', 'إقتصاد', 'الاقتصاد',
    'الإقتصاد', 'قانون', 'Law', 'مشاريع', 'Project', 'ريادة الأعمال', 'Entrepreneurship', 'تجارة', 'E-Commerce',
    'بنوك', 'Banking', 'تأمين', 'Insurance', 'تحليل مالي', 'Financial Analysis', 'حوكمة', 'Corporate Governance',
    'موارد', 'مالية', 'ماليه', 'المالية', 'الماليه', 'حقوق', 'الحقوق', 'Emba', 'Mba', 'Pmp', 'علوم القرارات',
    'سكرتير تنفيذي', 'علاقات عامه', 'اتصال استراتيجي', 'الادلة الجنائية', 'Ebusiness', 'Actuarial Science', 'علوم امنية', 'قيادة وتخطيط'
]
patternB = '|'.join(keywordsB)
traindf.loc[traindf['Education Speciality'].str.contains(patternB, na=False), 'College'] = 'الأعمال والإدارة والقانون'


# === العلوم الاجتماعية والصحافة والإعلام ===
keywordsS = [
    'تاريخ', 'تاريخيه', 'تاريخية', 'التاريخ', 'التاريخيه', 'التاريخية', 'History',
    'صحافة', 'صحافه', 'الصحافة', 'الصحافه', 'Journalism', 'اعلام', 'الإعلام', 'والإعلام', 'Media',
    'اجتماعيات', 'Social Studies', 'اجتماعية', 'اجتماعيه', 'اجتماع', 'النفس', 'نفس', 'التوجية والاصلاح الاسري'
]
patternS = '|'.join(keywordsS)
traindf.loc[traindf['Education Speciality'].str.contains(patternS, na=False), 'College'] = 'العلوم الاجتماعية والصحافة والإعلام'


# === الفنون والعلوم الإنسانية ===
keywordsLan = [
    'انجليزي', 'إنجليزي', 'الانجليزي', 'الإنجليزي', 'English', 'انجليزيه', 'الانجليزيه', 'إنجليزيه', 'الإنجليزيه',
    'عربي', 'العربي', 'عربية', 'العربية', 'عربيه', 'العربيه', 'Arabic', 'لغه', 'اللغه', 'لغة', 'اللغة', 'اللغات',
    'لغات', 'ترجمة', 'ترجمه', 'الترجمة', 'الترجمه', 'فنية', 'فنيه', 'الفنية', 'الفنيه', 'Art Education',
    'Art And Design', 'Multimedia', 'Interiot', 'Design', 'تصميم', 'Product Design', 'تصميم المنتجات', 'تصميم داخلي',
    'تصميم ازياء', 'تصميم مواقع', 'فنون بصرية', 'فنون بصرية نحت', 'نحت فنون بصرية', 'الجرافيكس والوسائط المتعددة',
    'التصميم الجرافيكي والوسائط المتعددة', 'تصميم منتحات', 'تصميم الازياء', 'جرافيك ووسائط رقمية', 'وسائط متعددة تفاعلية',
    'تصميم جرافيكي ووسائط متعددة', 'الوسائط المتعددة ورسومات الويب', 'تصميم منتجات Product Design',
    'Products Design', 'Product Design', 'Language', 'اللغويات التطبيقية', 'لغويات تطبيقية'
]
patternLan = '|'.join(keywordsLan)
traindf.loc[traindf['Education Speciality'].str.contains(patternLan, na=False), 'College'] = 'الفنون والعلوم الإنسانية'

# === العلوم الدينية ===
keywordsRE = [
    'أصول الدين', 'اصول دين', 'القرأن الكريم والدراسات الاسلاميه',
    'دراسات إسلامية', 'دراسات اسلامية', 'دراسات اسلاميه', 'دراسات الإسلاميه',
    'الشريعة', 'دراسات وقضايا معاصرة'
]
patternRE = '|'.join(keywordsRE)
traindf.loc[traindf['Education Speciality'].str.contains(patternRE, na=False), 'College'] = 'العلوم الدينية'

# === التعليم ===
keywordsEdu = [
    'تعليم', 'التعليم', 'تقنيات التعليم', 'تقنيات تعليم', 'التعليم الإلكتروني', 'تعليم إلكتروني',
    'مناهج وطرق تدريس', 'المناهج وطرق التدريس',
    'رياض اطفال', 'تعليم ماقبل المرحلة الابتدائية',
    'تربية', 'تربوي', 'تربية خاصة', 'تربيه خاصة صعوبات تعلم', 'تربية خاصه', 'تربية فكريه',
    'Special Education', 'Education', 'Curriculum', 'Early Childhood',
    'Educational Technology', 'Kindergarten', 'Teacher', 'Teaching', 'المدربين'
]
patternEdu = '|'.join(keywordsEdu)
traindf.loc[traindf['Education Speciality'].str.contains(patternEdu, na=False), 'College'] = 'التعليم'

# %% [markdown]
# ### Filling Missing Values in Program Sub Category Code
#
# In this section, we will fill the missing values in the "Program Sub Category Code" column with the label "No sub." This is appropriate since a subcategory is not required to exist for every program.

# %%
traindf['Program Sub Category Code'] = traindf['Program Sub Category Code'].fillna('No sub')

# %% [markdown]
# ### Finalizing the DataFrame
#
# If you want to ensure that only rows with relevant data in the "Still Working" and "College" columns remain, you can drop the rows where both are missing.

# %%
traindf = traindf.dropna(subset=['Still Working', 'College'], how='all')
traindf
# Out:
#                                 Student ID  Age  Gender    Home Region  \
# 0     4f14c50d-162e-4a15-9cf0-ec129c33bcf0   37    Male  Riyadh Region
# 1     0599d409-876b-41a5-af05-749ef0e77d32   21    Male    Asir Region
# 2     38a11c0e-4afc-4261-9c64-e94cc0a272fb   24    Male  Riyadh Region
# 3     1693e85b-f80e-40ce-846f-395ddcece6d3   23    Male  Riyadh Region
# 4     98a0e8d0-5f80-4634-afd8-322aa0902863   23    Male  Riyadh Region
# ...                                    ...  ...     ...            ...
# 6543  cd196579-9590-441b-8787-41078f3cee25   31  Female  Riyadh Region
# 6544  37bfc11c-ff8c-42dc-9cf9-0d13bb8f7131   27  Female  Qassim Region
# 6545  fc114302-a79f-439f-a08b-fe0a51cf839e   24  Female  Riyadh Region
# 6546  4b6d9a36-4402-4c75-bc3a-fca927dbaf65   25    Male  Riyadh Region
# 6547  008f3386-0d43-45a4-8372-b282e5a0101a   37  Female  Riyadh Region
#
#            Home City                            Program ID  \
# 0             Riyadh  453686d8-4023-4506-b2df-fac8b059ac26
# 1     Khamis Mushait  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60
# 2             Riyadh  e006900d-05a9-4c2b-a36f-0ffb9fce44cd
# 3             Riyadh  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9
# 4             Riyadh  d32da0e9-1aed-48c3-992d-a22f9ccc741e
# ...              ...                                   ...
# 6543          Riyadh  4f8c696a-b783-4d40-9776-105f6d3bd624
# 6544        Buraidah  e94942dd-8684-4746-97ae-df567b9b0a4a
# 6545          Riyadh  02ae0b47-64a6-47a1-b3c5-c0e4df393c30
# 6546          Riyadh  9b4cedaa-fac0-4eac-aa4b-b05b6a0c97ff
# 6547          Riyadh  d8fbc53c-e042-4e45-b8c7-42b4ad0528ee
#
#      Program Main Category Code Program Sub Category Code Technology Type  \
# 0                          PCRF                      PCRF     Traditional
# 1                          APMR                      SWPS      Supportive
# 2                          APMR                    No sub     Traditional
# 3                          TOSL                      TOSL     Traditional
# 4                          CAUF                      SWPS     Traditional
# ...                         ...                       ...             ...
# 6543                       CAUF                      SWPS     Traditional
# 6544                       PCRF                      PCRF     Traditional
# 6545                       PCRF                      PCRF     Traditional
# 6546                       PCRF                      PCRF     Traditional
# 6547                       CAUF                    No sub      Supportive
#
#      Program Skill Level  ... Completed Degree Level of Education  \
# 0           Intermediate  ...              Yes           Bachelor
# 1           Intermediate  ...              Yes           Bachelor
# 2           Intermediate  ...              Yes           Bachelor
# 3           Intermediate  ...              Yes           Bachelor
# 4           Intermediate  ...               No           Bachelor
# ...                  ...  ...              ...                ...
# 6543            Beginner  ...              Yes           Bachelor
# 6544            Beginner  ...              Yes           Bachelor
# 6545            Beginner  ...               No           Bachelor
# 6546        Intermediate  ...              Yes           Bachelor
# 6547            Beginner  ...              Yes             Master
#
#                      Education Speciality                         College  \
# 0                        هندسة حاسب الالي  تكنولوجيا الاتصالات والمعلومات
# 1              الإذاعة والتلفزيون والفيلم             Arts and Humanities
# 2                  Information Technology  تكنولوجيا الاتصالات والمعلومات
# 3     حوسبة تطبيقية - (مسار شبكات الحاسب)  تكنولوجيا الاتصالات والمعلومات
# 4                 نظم المعلومات الحاسوبية  تكنولوجيا الاتصالات والمعلومات
# ...                                   ...                             ...
# 6543                      تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6544                          علوم الحاسب  تكنولوجيا الاتصالات والمعلومات
# 6545                        نظم المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6546                      تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6547                 دراسات وقضايا معاصرة                  العلوم الدينية
#
#      University Degree Score University Degree Score System Employment Status  \
# 0                       2.44                            4.0        Unemployed
# 1                       5.00                            5.0           Student
# 2                       3.50                            5.0          Employed
# 3                       3.55                            5.0          Graduate
# 4                       4.00                            5.0               NaN
# ...                      ...                            ...               ...
# 6543                    4.40                            5.0               NaN
# 6544                    4.46                            5.0          Employed
# 6545                    4.93                            5.0          Employed
# 6546                    4.00                            4.0        Unemployed
# 6547                    4.32                            5.0          Employed
#
#        Job Type  Still Working  Y
# 0        No Job             No  0
# 1        No Job             No  0
# 2     Full-time            Yes  0
# 3        No Job             No  0
# 4           NaN            NaN  0
# ...         ...            ... ..
# 6543        NaN            NaN  0
# 6544  Full-time            Yes  0
# 6545  Full-time            Yes  1
# 6546     No Job             No  0
# 6547  Full-time            Yes  0
#
# [6417 rows x 24 columns]

# %%
missing = traindf.isnull().sum().sort_values(ascending=False)
print(missing[missing > 0])
# Out:
# Employment Status    478
# Job Type             478
# Still Working        478
# College              200
# Age                   15
# Home Region            1
# Home City              1
# dtype: int64

# %% [markdown]
# ### Filling College Column for High School Students
#
# To fill the "College" column with "No colloge" for students who are in high school, you can use the following approach:

# %%
traindf.loc[traindf['Level of Education'] == 'Secondary', 'College'] = 'No College'

# %% [markdown]
# ### Dropping Remaining Null Rows in College Column
#
# If after filling the "College" column for high school students, you find that only 4 null rows remain, you can drop those rows to clean up your DataFrame.

# %%
traindf[traindf['College'].isna()]
# Out:
#                                 Student ID  Age  Gender    Home Region  \
# 1157  e26065dc-956f-4fcd-9d3c-1a30e38829c2   42    Male  Riyadh Region
# 1670  a50e88b3-32a2-4de1-8c05-94e13d3d63c2   47    Male  Riyadh Region
# 2040  a631a556-19de-4c1a-8786-34f36c502a5c   27  Female  Riyadh Region
# 2751  896ef0f6-744a-415d-b799-6eebddf944b8   19  Female  Riyadh Region
# 5628  854fd98d-a0c7-4197-8670-6f2301e9d476   21  Female  Riyadh Region
# 5776  9fedbc0b-f2e1-4171-b1fb-2b5e50aa2b55   22    Male  Riyadh Region
#
#      Home City                            Program ID  \
# 1157    Riyadh  3218820e-5fc3-4dcb-8c23-17ac8de5e4b0
# 1670    Riyadh  4f8c696a-b783-4d40-9776-105f6d3bd624
# 2040    Riyadh  b9d1b38d-44e0-4943-a008-8cb527a88f3c
# 2751    Riyadh  4957a013-46a7-419c-93d5-ebf3741ab2a1
# 5628    Riyadh  e6be9f1a-dffa-4662-a7d2-74a6e12ad4b2
# 5776    Riyadh  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9
#
#      Program Main Category Code Program Sub Category Code Technology Type  \
# 1157                       GRST                      INFA     Traditional
# 1670                       CAUF                      SWPS     Traditional
# 2040                       APMR                      SRTA     Traditional
# 2751                       PCRF                      PCRF     Traditional
# 5628                       CAUF                      SWPS      Supportive
# 5776                       TOSL                      TOSL     Traditional
#
#      Program Skill Level  ... Completed Degree Level of Education  \
# 1157        Intermediate  ...              Yes            Diploma
# 1670            Beginner  ...              Yes                PhD
# 2040        Intermediate  ...               No             Master
# 2751            Beginner  ...               No           Bachelor
# 5628            Beginner  ...              Yes           Bachelor
# 5776            Beginner  ...              Yes           Bachelor
#
#      Education Speciality  College University Degree Score  \
# 1157                  علو      NaN                    3.00
# 1670            Inter-iot      NaN                    4.85
# 2040           E-business      NaN                    4.60
# 2751          تحضيري علمي      NaN                    4.88
# 5628              السياحة      NaN                    5.00
# 5776     جامعة الملك سعود      NaN                    4.53
#
#      University Degree Score System Employment Status   Job Type  \
# 1157                            4.0          Employed  Full-time
# 1670                            5.0         Freelance   Flexible
# 2040                            5.0          Employed  Full-time
# 2751                            5.0           Student     No Job
# 5628                            5.0          Graduate     No Job
# 5776                            5.0           Student     No Job
#
#       Still Working  Y
# 1157            Yes  0
# 1670            Yes  0
# 2040            Yes  1
# 2751             No  0
# 5628             No  0
# 5776             No  0
#
# [6 rows x 24 columns]

# %% [markdown]
# ### Dropping Rows with Missing Values in Specific Columns
#
# To ensure that your DataFrame only contains rows with non-null values in the specified columns, you can drop rows where either "Still Working" or "College" has missing values.

# %%
traindf = traindf.dropna(subset=['Still Working'])
traindf = traindf.dropna(subset=['College'])

# %%
traindf[traindf['Age'].isna()]
# Out:
#                                 Student ID   Age  Gender       Home Region  \
# 141   3b792401-76ab-411a-bb84-b62ced139e64  <NA>  Female     Riyadh Region
# 523   822d6986-8a43-4342-928f-ebf8b0014f05  <NA>    Male  Eastern Province
# 1349  822d6986-8a43-4342-928f-ebf8b0014f05  <NA>    Male  Eastern Province
# 4340  3b792401-76ab-411a-bb84-b62ced139e64  <NA>  Female     Riyadh Region
# 4377  03fb5ad5-55b3-4064-b8df-313bec5b2b10  <NA>    Male     Riyadh Region
# 4904  0199e322-e968-4637-8fee-5cc622c3adcc  <NA>  Female     Riyadh Region
# 5013  782c9649-1b29-452a-bb95-bdd2f89db042  <NA>    Male     Riyadh Region
# 5049  782c9649-1b29-452a-bb95-bdd2f89db042  <NA>    Male     Riyadh Region
# 5132  1f0c3148-3705-45a0-b171-5b2a9334595a  <NA>    Male       Asir Region
# 5348  03fb5ad5-55b3-4064-b8df-313bec5b2b10  <NA>    Male     Riyadh Region
# 5981  e482a4a3-c7d0-4f19-916f-8ab7dda42dcd  <NA>    Male      Tabuk Region
#
#      Home City                            Program ID  \
# 141     Riyadh  3ec67853-6b57-48cc-9bc6-956e286a7c65
# 523     Jubail  5364b84a-0ed3-4e1c-9b7d-5a5cf1e14b20
# 1349    Jubail  ca70e847-57d2-4aad-862a-423e3076577a
# 4340    Riyadh  4ad7a7dc-abcf-43fa-b2e3-07095e083661
# 4377    Riyadh  67bbe41c-20c2-4799-9e15-eaae2e94f157
# 4904    Riyadh  3ec67853-6b57-48cc-9bc6-956e286a7c65
# 5013    Riyadh  f2374bcb-111c-402d-beaf-37433687db4d
# 5049    Riyadh  9144fab5-59f3-4b98-bc3c-0784a04883fe
# 5132      Abha  013916fa-85bd-46bc-80c8-f37c036fd142
# 5348    Riyadh  e006900d-05a9-4c2b-a36f-0ffb9fce44cd
# 5981     Tabuk  f6f76cca-98bf-405f-9853-44c838c54c71
#
#      Program Main Category Code Program Sub Category Code Technology Type  \
# 141                        CAUF                      ERST     Traditional
# 523                        CAUF                      SWPS     Traditional
# 1349                       CAUF                      SWPS     Traditional
# 4340                       PCRF                      PCRF     Traditional
# 4377                       APMR                    No sub     Traditional
# 4904                       CAUF                      ERST     Traditional
# 5013                       TOSL                    No sub     Traditional
# 5049                       TOSL                      TOSL      Supportive
# 5132                       PCRF                      PCRF     Traditional
# 5348                       APMR                    No sub     Traditional
# 5981                       APMR                    No sub     Traditional
#
#      Program Skill Level  ... Completed Degree Level of Education  \
# 141         Intermediate  ...               No           Bachelor
# 523             Beginner  ...              Yes          Secondary
# 1349        Intermediate  ...              Yes          Secondary
# 4340            Advanced  ...               No           Bachelor
# 4377        Intermediate  ...              Yes          Secondary
# 4904        Intermediate  ...              Yes           Bachelor
# 5013            Beginner  ...              Yes          Secondary
# 5049            Advanced  ...              Yes          Secondary
# 5132            Advanced  ...              Yes          Secondary
# 5348        Intermediate  ...              Yes          Secondary
# 5981            Advanced  ...               No           Bachelor
#
#                      Education Speciality                         College  \
# 141                نظم المعلومات الادارية  تكنولوجيا الاتصالات والمعلومات
# 523                                                            No College
# 1349                                                           No College
# 4340               نظم المعلومات الادارية  تكنولوجيا الاتصالات والمعلومات
# 4377                                                           No College
# 4904  Management Information System (mis)       الأعمال والإدارة والقانون
# 5013                                                           No College
# 5049                                                           No College
# 5132                                                           No College
# 5348                                                           No College
# 5981                          علوم الحاسب  تكنولوجيا الاتصالات والمعلومات
#
#      University Degree Score University Degree Score System Employment Status  \
# 141                     4.99                            5.0          Graduate
# 523                    88.00                          100.0           Student
# 1349                   88.00                          100.0           Student
# 4340                    4.99                            5.0          Graduate
# 4377                   99.00                          100.0           Student
# 4904                    4.90                            5.0          Graduate
# 5013                   99.13                          100.0           Student
# 5049                   99.13                          100.0           Student
# 5132                   97.00                          100.0           Student
# 5348                   99.00                          100.0           Student
# 5981                    4.25                            5.0          Graduate
#
#      Job Type  Still Working  Y
# 141    No Job             No  1
# 523    No Job             No  0
# 1349   No Job             No  0
# 4340   No Job             No  1
# 4377   No Job             No  0
# 4904   No Job             No  0
# 5013   No Job             No  0
# 5049   No Job             No  0
# 5132   No Job             No  0
# 5348   No Job             No  0
# 5981   No Job             No  0
#
# [11 rows x 24 columns]

# %%
missing = traindf.isnull().sum().sort_values(ascending=False)
print(missing[missing > 0])
# Out:
# Age            11
# Home Region     1
# Home City       1
# dtype: int64

# %% [markdown]
# ### Filling Age for Secondary School Students
#
# To fill the "Age" column with random values between 16 and 18 for students in secondary school who currently have missing age values, you can use the following code:

# %%
mask_secondary = (traindf['Level of Education'] == 'Secondary') & (traindf['Age'].isna())
traindf.loc[mask_secondary, 'Age'] = np.random.randint(16, 19, size=mask_secondary.sum())

# %% [markdown]
# ### Filling Age for Bachelor Students
#
# To fill the "Age" column with random values between 18 and 30 for students in the bachelor program who currently have missing age values, you can use the following code:

# %%
mask_bachelor = (traindf['Level of Education'] == 'Bachelor') & (traindf['Age'].isna())
traindf.loc[mask_bachelor, 'Age'] = np.random.randint(18, 31, size=mask_bachelor.sum())

# %%
missing = traindf.isnull().sum().sort_values(ascending=False) # Check null values and sort them
print(missing[missing > 0])
# Out:
# Home Region    1
# Home City      1
# dtype: int64

# %% [markdown]
# ### Checking and Dropping Rows with Null Values in Home Region and Home City
#
# If you find that both "Home Region" and "Home City" are null for certain rows, and since you cannot determine their values, you can drop these rows from the DataFrame.

# %%
print(traindf[traindf['Home Region'].isnull() & traindf['Home City'].isnull()])
# Out:
#                                 Student ID  Age Gender Home Region Home City  \
# 1864  cc394a25-74ed-43f9-92bc-e0021fc969c5   45   Male         NaN       NaN
#
#                                 Program ID Program Main Category Code  \
# 1864  ce3562c8-8d27-4ffb-8dfc-e1dd4527b32a                       PCRF
#
#      Program Sub Category Code Technology Type Program Skill Level  ...  \
# 1864                      PCRF     Traditional            Beginner  ...
#
#      Completed Degree Level of Education    Education Speciality  \
# 1864              Yes             Master  نظم المعلومات الإدارية
#
#                              College University Degree Score  \
# 1864  تكنولوجيا الاتصالات والمعلومات                     4.0
#
#      University Degree Score System Employment Status   Job Type  \
# 1864                            5.0          Employed  Full-time
#
#       Still Working  Y
# 1864            Yes  0
#
# [1 rows x 24 columns]

# %%
traindf = traindf[~(traindf['Home Region'].isnull() & traindf['Home City'].isnull())] # Dropping Home City, since Home Region is also null so there is no way of knowing the city.

# %%
missing = traindf.isnull().sum().sort_values(ascending=False)
print(missing[missing > 0])
# Out:
# Series([], dtype: int64)

# %%
traindf
# Out:
#                                 Student ID  Age  Gender    Home Region  \
# 0     4f14c50d-162e-4a15-9cf0-ec129c33bcf0   37    Male  Riyadh Region
# 1     0599d409-876b-41a5-af05-749ef0e77d32   21    Male    Asir Region
# 2     38a11c0e-4afc-4261-9c64-e94cc0a272fb   24    Male  Riyadh Region
# 3     1693e85b-f80e-40ce-846f-395ddcece6d3   23    Male  Riyadh Region
# 5     6b27cd77-23aa-438b-bd0b-7abdb40a717c   30    Male  Riyadh Region
# ...                                    ...  ...     ...            ...
# 6542  537cbf47-e5c8-4ff8-a636-ea3aa34c36b0   25  Female  Riyadh Region
# 6544  37bfc11c-ff8c-42dc-9cf9-0d13bb8f7131   27  Female  Qassim Region
# 6545  fc114302-a79f-439f-a08b-fe0a51cf839e   24  Female  Riyadh Region
# 6546  4b6d9a36-4402-4c75-bc3a-fca927dbaf65   25    Male  Riyadh Region
# 6547  008f3386-0d43-45a4-8372-b282e5a0101a   37  Female  Riyadh Region
#
#            Home City                            Program ID  \
# 0             Riyadh  453686d8-4023-4506-b2df-fac8b059ac26
# 1     Khamis Mushait  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60
# 2             Riyadh  e006900d-05a9-4c2b-a36f-0ffb9fce44cd
# 3             Riyadh  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9
# 5             Riyadh  32bce2ad-426a-4096-b7d0-78b5f30bd8a0
# ...              ...                                   ...
# 6542          Riyadh  bf68a9ad-0543-4e6e-8a42-695953db697a
# 6544        Buraidah  e94942dd-8684-4746-97ae-df567b9b0a4a
# 6545          Riyadh  02ae0b47-64a6-47a1-b3c5-c0e4df393c30
# 6546          Riyadh  9b4cedaa-fac0-4eac-aa4b-b05b6a0c97ff
# 6547          Riyadh  d8fbc53c-e042-4e45-b8c7-42b4ad0528ee
#
#      Program Main Category Code Program Sub Category Code Technology Type  \
# 0                          PCRF                      PCRF     Traditional
# 1                          APMR                      SWPS      Supportive
# 2                          APMR                    No sub     Traditional
# 3                          TOSL                      TOSL     Traditional
# 5                          ABIR                      INFA        Emerging
# ...                         ...                       ...             ...
# 6542                       CAUF                      SWPS        Emerging
# 6544                       PCRF                      PCRF     Traditional
# 6545                       PCRF                      PCRF     Traditional
# 6546                       PCRF                      PCRF     Traditional
# 6547                       CAUF                    No sub      Supportive
#
#      Program Skill Level  ... Completed Degree Level of Education  \
# 0           Intermediate  ...              Yes           Bachelor
# 1           Intermediate  ...              Yes           Bachelor
# 2           Intermediate  ...              Yes           Bachelor
# 3           Intermediate  ...              Yes           Bachelor
# 5               Beginner  ...              Yes           Bachelor
# ...                  ...  ...              ...                ...
# 6542        Intermediate  ...              Yes           Bachelor
# 6544            Beginner  ...              Yes           Bachelor
# 6545            Beginner  ...               No           Bachelor
# 6546        Intermediate  ...              Yes           Bachelor
# 6547            Beginner  ...              Yes             Master
#
#                      Education Speciality                         College  \
# 0                        هندسة حاسب الالي  تكنولوجيا الاتصالات والمعلومات
# 1              الإذاعة والتلفزيون والفيلم             Arts and Humanities
# 2                  Information Technology  تكنولوجيا الاتصالات والمعلومات
# 3     حوسبة تطبيقية - (مسار شبكات الحاسب)  تكنولوجيا الاتصالات والمعلومات
# 5                          هندسة حاسب آلي  تكنولوجيا الاتصالات والمعلومات
# ...                                   ...                             ...
# 6542                          علوم الحاسب  تكنولوجيا الاتصالات والمعلومات
# 6544                          علوم الحاسب  تكنولوجيا الاتصالات والمعلومات
# 6545                        نظم المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6546                      تقنية المعلومات  تكنولوجيا الاتصالات والمعلومات
# 6547                 دراسات وقضايا معاصرة                  العلوم الدينية
#
#      University Degree Score University Degree Score System Employment Status  \
# 0                       2.44                            4.0        Unemployed
# 1                       5.00                            5.0           Student
# 2                       3.50                            5.0          Employed
# 3                       3.55                            5.0          Graduate
# 5                       4.07                            5.0          Employed
# ...                      ...                            ...               ...
# 6542                    4.20                            5.0          Employed
# 6544                    4.46                            5.0          Employed
# 6545                    4.93                            5.0          Employed
# 6546                    4.00                            4.0        Unemployed
# 6547                    4.32                            5.0          Employed
#
#        Job Type  Still Working  Y
# 0        No Job             No  0
# 1        No Job             No  0
# 2     Full-time            Yes  0
# 3        No Job             No  0
# 5     Full-time            Yes  0
# ...         ...            ... ..
# 6542  Full-time            Yes  0
# 6544  Full-time            Yes  0
# 6545  Full-time            Yes  1
# 6546     No Job             No  0
# 6547  Full-time            Yes  0
#
# [5932 rows x 24 columns]

# %% [markdown]
# ### Dropping the Education Specialty Column
#
#
# To remove the "Education Specialty" column from the DataFrame due to its inconsistent values and non-essential nature for prediction, you can use the following code:

# %%
traindf.drop(columns=['Education Speciality'], inplace=True)

print(traindf.head())
# Out:
#                              Student ID  Age Gender    Home Region  \
# 0  4f14c50d-162e-4a15-9cf0-ec129c33bcf0   37   Male  Riyadh Region
# 1  0599d409-876b-41a5-af05-749ef0e77d32   21   Male    Asir Region
# 2  38a11c0e-4afc-4261-9c64-e94cc0a272fb   24   Male  Riyadh Region
# 3  1693e85b-f80e-40ce-846f-395ddcece6d3   23   Male  Riyadh Region
# 5  6b27cd77-23aa-438b-bd0b-7abdb40a717c   30   Male  Riyadh Region
#
#         Home City                            Program ID  \
# 0          Riyadh  453686d8-4023-4506-b2df-fac8b059ac26
# 1  Khamis Mushait  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60
# 2          Riyadh  e006900d-05a9-4c2b-a36f-0ffb9fce44cd
# 3          Riyadh  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9
# 5          Riyadh  32bce2ad-426a-4096-b7d0-78b5f30bd8a0
#
#   Program Main Category Code Program Sub Category Code Technology Type  \
# 0                       PCRF                      PCRF     Traditional
# 1                       APMR                      SWPS      Supportive
# 2                       APMR                    No sub     Traditional
# 3                       TOSL                      TOSL     Traditional
# 5                       ABIR                      INFA        Emerging
#
#   Program Skill Level  ... Program Days Completed Degree Level of Education  \
# 0        Intermediate  ...           12              Yes           Bachelor
# 1        Intermediate  ...            5              Yes           Bachelor
# 2        Intermediate  ...           54              Yes           Bachelor
# 3        Intermediate  ...           33              Yes           Bachelor
# 5            Beginner  ...           12              Yes           Bachelor
#
#                                     College University Degree Score  \
# 0  Information and Communication Technology                    2.44
# 1                       Arts and Humanities                    5.00
# 2  Information and Communication Technology                    3.50
# 3  Information and Communication Technology                    3.55
# 5  Information and Communication Technology                    4.07
#
#   University Degree Score System Employment Status   Job Type  Still Working  \
# 0                            4.0        Unemployed     No Job             No
# 1                            5.0           Student     No Job             No
# 2                            5.0          Employed  Full-time            Yes
# 3                            5.0          Graduate     No Job             No
# 5                            5.0          Employed  Full-time            Yes
#
#    Y
# 0  0
# 1  0
# 2  0
# 3  0
# 5  0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Feature Engineering: Creating Age Range by Program
#
# To create a new column that calculates the age range for each program based on the minimum and maximum ages, you can follow these steps:

# %%
age_ranges = traindf.groupby('Program ID')['Age'].agg(['min', 'max']).reset_index()

age_ranges['Age Range by Program'] = age_ranges['min'].astype(str) + '-' + age_ranges['max'].astype(str)

traindf = traindf.merge(age_ranges[['Program ID', 'Age Range by Program']], on='Program ID', how='left')

# %% [markdown]
# ### Feature Engineering: Calculating Program Duration
#
# To create a new feature that calculates the duration of each program in days based on the start and end dates, you can use the following code:

# %%
traindf['Program Start Date'] = pd.to_datetime(traindf['Program Start Date'])
traindf['Program End Date'] = pd.to_datetime(traindf['Program End Date'])

traindf['Program Duration'] = (traindf['Program End Date'] - traindf['Program Start Date']).dt.days

print(traindf.head())
# Out:
#                              Student ID  Age Gender    Home Region  \
# 0  4f14c50d-162e-4a15-9cf0-ec129c33bcf0   37   Male  Riyadh Region
# 1  0599d409-876b-41a5-af05-749ef0e77d32   21   Male    Asir Region
# 2  38a11c0e-4afc-4261-9c64-e94cc0a272fb   24   Male  Riyadh Region
# 3  1693e85b-f80e-40ce-846f-395ddcece6d3   23   Male  Riyadh Region
# 4  6b27cd77-23aa-438b-bd0b-7abdb40a717c   30   Male  Riyadh Region
#
#         Home City                            Program ID  \
# 0          Riyadh  453686d8-4023-4506-b2df-fac8b059ac26
# 1  Khamis Mushait  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60
# 2          Riyadh  e006900d-05a9-4c2b-a36f-0ffb9fce44cd
# 3          Riyadh  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9
# 4          Riyadh  32bce2ad-426a-4096-b7d0-78b5f30bd8a0
#
#   Program Main Category Code Program Sub Category Code Technology Type  \
# 0                       PCRF                      PCRF     Traditional
# 1                       APMR                      SWPS      Supportive
# 2                       APMR                    No sub     Traditional
# 3                       TOSL                      TOSL     Traditional
# 4                       ABIR                      INFA        Emerging
#
#   Program Skill Level  ... Level of Education  \
# 0        Intermediate  ...           Bachelor
# 1        Intermediate  ...           Bachelor
# 2        Intermediate  ...           Bachelor
# 3        Intermediate  ...           Bachelor
# 4            Beginner  ...           Bachelor
#
#                                     College University Degree Score  \
# 0  Information and Communication Technology                    2.44
# 1                       Arts and Humanities                    5.00
# 2  Information and Communication Technology                    3.50
# 3  Information and Communication Technology                    3.55
# 4  Information and Communication Technology                    4.07
#
#    University Degree Score System Employment Status   Job Type Still Working  \
# 0                             4.0        Unemployed     No Job            No
# 1                             5.0           Student     No Job            No
# 2                             5.0          Employed  Full-time           Yes
# 3                             5.0          Graduate     No Job            No
# 4                             5.0          Employed  Full-time           Yes
#
#    Y  Age Range by Program Program Duration
# 0  0                 24-37               11
# 1  0                 20-46                4
# 2  0                 16-33               53
# 3  0                 21-38               32
# 4  0                 20-43               11
#
# [5 rows x 25 columns]

# %%
traindf.head(5)
# Out:
#                              Student ID  Age Gender    Home Region  \
# 0  4f14c50d-162e-4a15-9cf0-ec129c33bcf0   37   Male  Riyadh Region
# 1  0599d409-876b-41a5-af05-749ef0e77d32   21   Male    Asir Region
# 2  38a11c0e-4afc-4261-9c64-e94cc0a272fb   24   Male  Riyadh Region
# 3  1693e85b-f80e-40ce-846f-395ddcece6d3   23   Male  Riyadh Region
# 4  6b27cd77-23aa-438b-bd0b-7abdb40a717c   30   Male  Riyadh Region
#
#         Home City                            Program ID  \
# 0          Riyadh  453686d8-4023-4506-b2df-fac8b059ac26
# 1  Khamis Mushait  cc8e4e42-65d5-4fa1-82f9-6c6c2d508b60
# 2          Riyadh  e006900d-05a9-4c2b-a36f-0ffb9fce44cd
# 3          Riyadh  2ec15f6b-233b-428a-b9f5-e40bc8d14cf9
# 4          Riyadh  32bce2ad-426a-4096-b7d0-78b5f30bd8a0
#
#   Program Main Category Code Program Sub Category Code Technology Type  \
# 0                       PCRF                      PCRF     Traditional
# 1                       APMR                      SWPS      Supportive
# 2                       APMR                    No sub     Traditional
# 3                       TOSL                      TOSL     Traditional
# 4                       ABIR                      INFA        Emerging
#
#   Program Skill Level  ... Level of Education  \
# 0        Intermediate  ...           Bachelor
# 1        Intermediate  ...           Bachelor
# 2        Intermediate  ...           Bachelor
# 3        Intermediate  ...           Bachelor
# 4            Beginner  ...           Bachelor
#
#                                     College University Degree Score  \
# 0  Information and Communication Technology                    2.44
# 1                       Arts and Humanities                    5.00
# 2  Information and Communication Technology                    3.50
# 3  Information and Communication Technology                    3.55
# 4  Information and Communication Technology                    4.07
#
#    University Degree Score System Employment Status   Job Type Still Working  \
# 0                             4.0        Unemployed     No Job            No
# 1                             5.0           Student     No Job            No
# 2                             5.0          Employed  Full-time           Yes
# 3                             5.0          Graduate     No Job            No
# 4                             5.0          Employed  Full-time           Yes
#
#    Y  Age Range by Program Program Duration
# 0  0                 24-37               11
# 1  0                 20-46                4
# 2  0                 16-33               53
# 3  0                 21-38               32
# 4  0                 20-43               11
#
# [5 rows x 25 columns]

# %%
traindf.to_csv('train_cleaned.csv', index=False)
